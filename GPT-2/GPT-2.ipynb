# %% [markdown]
# # Introduction
# This is the training phase of GPT-2. Elaborated in our report and presentation, we have decided to train on both general and food models.
# ###  Setup
# 1. Ensure that gpt-2-simple package is installed and you have sufficient RAM and GPU to train the large model
# 2. Make sure that dataset is in same folder
# 3. This was trained in Colab with GPU and High RAM (30GB RAM) and Google Cloud Platform (1x P100 GPU and 15GB n1-standard-4 CPUs)
# 4. Ensure you have at least 10 GB of harddisk space
#
# --------------------------------
# # Content
# This is the breakdown of the Notebook
# #####  1. Final Training stage of GPT-2
#     a. Trained on General (Review star 1)
#     b. Trained on General (Review star 5)
#     c. Trained on Food (Review star 1)
#     d. Trained on Food (Review star 5)
# ##### 2. Sample Generation of Text
#     a. General model (Review star 1)
#     b. General model (Review star 5)
#     c. Food model (Review star 1)
#     d. Food model (Review star 5)
#
# ----------------------------------
# # Summary of Findings:
# 1. GPT-2 Large is able to generate complex sentences consistently even though it is only trained on 5000 epochs
# 2. It takes about 45 secs to generate 3 samples with a length of 10 from a Large model
# 3. For the text generated to be of better quality, it is recommended to provide more context rather than giving a general input like "I like the"

# %%
# !pip install gpt-2-simple
# Out:
# Requirement already satisfied: gpt-2-simple in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (0.7.1)
# Requirement already satisfied: requests in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (from gpt-2-simple) (2.22.0)
# Requirement already satisfied: regex in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (from gpt-2-simple) (2020.1.8)
# Requirement already satisfied: tqdm in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (from gpt-2-simple) (4.42.1)
# Requirement already satisfied: toposort in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (from gpt-2-simple) (1.5)
# Requirement already satisfied: numpy in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (from gpt-2-simple) (1.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (from requests->gpt-2-simple) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (from requests->gpt-2-simple) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (from requests->gpt-2-simple) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zhehao/anaconda3/envs/BT4222/lib/python3.6/site-packages (from requests->gpt-2-simple) (2019.11.28)

# %%
import gpt_2_simple as gpt2
from datetime import datetime
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ### Training for GPT2 Large (Review 1 Filtered)

# %%
import gpt_2_simple as gpt2
import os
import requests

model_name = "774M"
file_name = "review_1_filtered.csv"

if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   

# %time
sess = gpt2.start_tf_sess()
gpt2.finetune(sess, \
              file_name, \
              model_name=model_name,\
              run_name = 'review_star_1_large', 
              steps=5000,
              print_every = 5)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.01 µs
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint checkpoint/review_star_1_large/model-9000
# INFO:tensorflow:Restoring parameters from checkpoint/review_star_1_large/model-9000
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:05<00:00,  5.82s/it]

# %% [markdown]
# ### Training for GPT2 large (Review 5 Filtered)

# %%
import gpt_2_simple as gpt2
import os
import requests

model_name = "774M"
file_name = "review_5_filtered.csv"

if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   

# %time
sess = gpt2.start_tf_sess()
gpt2.finetune(sess, \
              file_name, \
              model_name=model_name,\
              run_name = 'review_star_5_large', 
              steps=5000,
              print_every = 5)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint checkpoint/review_star_5_large/model-3000
# INFO:tensorflow:Restoring parameters from checkpoint/review_star_5_large/model-3000
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:06<00:00,  6.59s/it]
# dataset has 74649217 tokens
# Training...
# Saving checkpoint/review_star_5_large/model-3000
# ======== SAMPLE 1 ========
#  pretty little sweet for a salad dish, but it still tastes absolutely amazing after my 1/2-hour soak in my glass of water. I enjoyed the roasted barley with walnut vinaigrette and some grilled onion straws a little to my surprise. The service was also amazing. Great customer service. Definitely a great place to come and have a good meal. I will definitely be back and have to try some other food from the menu again on the regular or at one of my upcoming appointments.<|endoftext|>
# <|startoftext|>This is a huge improvement on the food and service I've had at many sushi restaurants in the area. The sushi was very fresh, the service was excellent and the prices were very fair.
#
# Everything I had was excellent and the sushi just overall were a pleasant experience. I'd definitely go back again in the future.<|endoftext|>
# <|startoftext|>I was in the area last year so I was looking around new restaurants in the area and decided to try this place out of sheer curiosity.
#
# It was at about 9pm on Thursday around 6pm. The whole staff were walking around and asking if you had any issues and that you were the most important person, and to their surprise they would ask how many times you had asked the waiter how many times, how long it took to get here, how bad you were...
#
# I got 3 different sushi plates and ordered 2-3 of the most popular things the restaurant asked me to do on the sushi. One of my favorites was the roll that was the most expensive.
#
# It was the Tama (rice) roll and it was just like a standard roll. The rice was soft and fluffy and the sushi was fresh. Not dry at all. I could feel my sushi getting sipped and was able to enjoy it as much as I wanted without leaving a big hole. Everything was very fresh and also very tasty.
#
# After my sushi came out I said "Wow, I was thinking that I need to eat this before my husband and I leave of this place and that I need to eat it because I want to live the whole experience and I want to thank them for making my experience so enjoyable for me".
#
# They are only 1/5 of a sushi price tag- but the service really made up for it.
#
# I would definitely recommend getting the sushi roll if you go in the first few minutes when they have an order of rolls (and you need to order the roll number that's available before the sushi is brought out)
#
# Also, they are only the 1-3 size sizes, so if you're not trying to eat in that particular place at 1/10, they are happy to seat you in the 5-10th size for you.
#
# My order came out as "O" and it was so big and my partner finished it with his own sushi for a $19.00. They were both excited about it.
#
# Our server gave us complimentary drink to settle down before he even got started.
#
# The customer service that was given while we ate our sushi in the back - he just wants to make sure everything is awesome and not the one he's eating. As always.
#
# I was so happy with our experience! We will definitely be back for more sushi in the future!<|endoftext|>
# <|startoftext|>This place is hands down the best place I ate at in Vegas for at least a few days a week and it's not a "big game" like some places.
#
# There's a reason this place gets 5 stars. It's because of the amazing staff. At one particular staff meeting a group of students sitting next to each other asked him how the server would have liked to drink the water when she was done. "She asked if I had ever had the option to purchase a bottle and I said no."
#
# That was it. Not a single student ever asked. He would have been pissed if I'd had him.
#
# I wasn't sure what to expect but it took about 20 seconds from then on the second day to my drink coming out. I was happy I could buy a drink. I got to try three different varieties. I ordered, "Old Fashion" with ginger/ginger syrup, ginger/ginger syrup & cranberry, and the "Super Old Fashion" with ginger/ginger.
#
# A year on from the first day, in all seriousness: I have finally found a place to drink my water at night that also has a good/lush smell in the place. I have to say that the place is one big step back for me from where the staff could do all of that for you.
#
# I also ordered the "Kitty" (saltwater glass) for both of the staff (a kinky cat - I think).
#
# I was so pleased with my coffee and all I could say
#
# [3005 | 515.99] loss=3.10 avg=3.10
# [3010 | 606.41] loss=2.93 avg=3.02
# [3015 | 696.17] loss=3.66 avg=3.23
# [3020 | 785.94] loss=3.10 avg=3.20
# [3025 | 874.57] loss=2.71 avg=3.10
# [3030 | 964.64] loss=3.09 avg=3.10
# [3035 | 1054.62] loss=3.01 avg=3.08
# [3040 | 1145.43] loss=3.43 avg=3.13
# [3045 | 1235.70] loss=2.96 avg=3.11
# [3050 | 1325.23] loss=3.21 avg=3.12
# [3055 | 1415.31] loss=2.61 avg=3.07
# [3060 | 1516.30] loss=2.98 avg=3.06
# [3065 | 1620.91] loss=3.32 avg=3.08
# [3070 | 1718.07] loss=3.46 avg=3.11
# [3075 | 1809.65] loss=3.46 avg=3.14
# [3080 | 1899.48] loss=2.95 avg=3.13
# [3085 | 1988.66] loss=2.90 avg=3.11
# [3090 | 2077.87] loss=3.02 avg=3.11
# [3095 | 2168.31] loss=2.87 avg=3.09
# [3100 | 2257.24] loss=3.22 avg=3.10
# ======== SAMPLE 1 ========
#  was it the right size. The sauce had a little kick to it, but not over the top. We enjoyed the fried chicken with the rice bowl with a spicy sauce. Great place. Will be back.<|endoftext|>
# <|startoftext|>A friend of mine introduced me to this place and I had always wanted pizza, but I was afraid to ask for a recommendation if it was so good. My friend and I stumbled on this place as we both went to school at the same university, so I had read the other reviews here and there on Yelp.
# We made our way in about a ten minute wait and were greeted, seated and even told to try the wings. I was a little apprehensive before going because I am a little afraid it will be crowded, but the ambiance is great. Great staff that are friendly and always making sure to give suggestions. What an adventure. We got our wings with buffalo and I swear I felt I was going to cry. They were delicious, spicy yet not too mush when served. We took our pizza home the next day and they were very friendly and made it perfect every time. I also had an entire pizza cut here and it was also great for an affordable price.
#
# Definitely will come back again. The quality is out of this world.<|endoftext|>
# <|startoftext|>We just came into town recently and we decided to just have breakfast at the local deli. We were greeted immediately and offered a drink in minutes. We had to find that one place. It was the one next to open, so we did not know anything about it, but figured we could get some great breakfast from it.
#
# We had a good seat by the window -- they have plenty of space to sit inside of (for a good reason).
#
# We started off with oatmeal buns and blueberries. Both meals were equally good!<|endoftext|>
# <|startoftext|>Best service in the business of chiropractic. Very nice staff! I was a victim of a major accident in the past, and the doctor was very thorough and knowledgeable. He really understands the things I have been through and is on a very well-tanned course. He was really very attentive to my needs as a patient. I had a very nice experience.<|endoftext|>
# <|startoftext|>We were here for a dinner and had a blast. We ordered the 5 course. They served my dinner with a beautiful redwareware box.  It was incredible. You can taste the ingredients. They have a very special tasting menu.  The food was delicious and the selection was great.
#
# I really enjoyed my meal as well. The lobster mac and cheese I had was to die for. The salad I had was too big to finish, but my husband did.
#
# The prices were very high, so we were pretty full after our meal.
#
# We will definitely be back.<|endoftext|>
# <|startoftext|>We ordered their fried chicken as the appetizer. The chicken was so tasty and the gravy was so good on it. I think there's just a tiny bit of salt, but it gives a really nice flavor. I had the whole chicken and he had the rice. Both were really delicious and the portions were huge. I could never finish the chicken. The soup we ordered was really really good because the soup was huge. For dessert, we had a strawberry shortcake. That's all.<|endoftext|>
# <|startoftext|>It's been over 6 months since I've been getting my eyebrows and my legs waxed, and the experience's just changed!! My first appointment was with Nicole on June 5th. She is so professional and takes the time to get to know you. She also does my brows! I am super careful because I feel like I get those bad ones that I'm going to get everywhere! No matter what I get, she is always great with how she's going. She also has an awesome selection of products from top notch brands...like a lot of places!
#
# I definitely feel better afterwards after my second appointment with Nicole. I've also gotten to go back about a half hour after my second appointment and can feel a little more calm about my brows and my legs. I also feel better and better after waxing my eyebrows. My brows are always perfect for me. I've also had my eyebrows done before with the same stylist and she always has a great experience with her work.
#
#
#
# I recommend going there!<|endoftext|>
# <|startoftext|>I've been going here since January of 2014. They have such a great selection of items. The pricing is just right and the staff is helpful. I have recommended this place to everyone I've gotten referrals to. My go
#
# [3105 | 2709.71] loss=3.02 avg=3.10
# [3110 | 2804.54] loss=3.13 avg=3.10
# [3115 | 2901.98] loss=2.26 avg=3.06
# [3120 | 2997.62] loss=2.91 avg=3.05
# [3125 | 3092.14] loss=2.90 avg=3.04
# [3130 | 3184.88] loss=2.93 avg=3.04
# [3135 | 3280.44] loss=2.90 avg=3.03
# [3140 | 3375.45] loss=3.22 avg=3.04
# [3145 | 3471.26] loss=2.86 avg=3.03
# [3150 | 3566.68] loss=3.15 avg=3.04
# [3155 | 3661.92] loss=3.16 avg=3.04
# [3160 | 3756.23] loss=2.82 avg=3.03
# [3165 | 3850.57] loss=3.32 avg=3.04
# [3170 | 3944.78] loss=3.06 avg=3.04
# [3175 | 4038.87] loss=3.13 avg=3.05
# [3180 | 4131.45] loss=3.21 avg=3.05
# [3185 | 4225.59] loss=3.13 avg=3.06
# [3190 | 4318.60] loss=2.92 avg=3.05
# [3195 | 4412.44] loss=2.60 avg=3.04
# [3200 | 4500.17] loss=2.86 avg=3.03
# ======== SAMPLE 1 ========
# Insurance policy, which is still on the books and it's in my car, the bill was $6.99 and I would definitely use this guy again. This guy has an insurance policy AND he's in my car. But I haven't been seeing this man in over a month. We contacted them and there was no response, and they said they couldn't help me. The problem is that it was only a "business" company. And they know this isn't the case. My insurance company doesn't care about your car and my rental car. They're there for you!  So now my car looks like I always got it, and I still have cash on hand! And that's what I'm talking about. That's what they do!
#
# So if you're like me and you have a business with a company that doesn't give a response - you need to try a new company! They'll give you that reply when they have the answer, I promise you.
#
# What you think? You've been on a shopping spree. Not just a bargain, you've also just found your car! But I hope they'll do it right, then call me the next day (or call them tomorrow), or in addition if you're at your old age, you can just use an insurance service (my car and rental service would be my service, though there's no insurance company in my town). You can also check the local store to see if they offer a rental, see if they have a repair shop, and have a look at their "booking" section.
#
# So, just go into a store for your rental. You're only going to find more value in keeping it as it is and keeping it looking brand new. Go to a nearby store and see where there the guy. You'll be happy you did.
#
# The lady who was there who told me they have been keeping it for months, she says, "Well it looks good on the website," which I really appreciated, "Well, the site says a great deal, and I can't deny the quote!" So I told her, "Well it might not look as clean on the website." I don't have a store and don't have a laptop, and now I'm only 5 and can't afford a laptop, so I don't have any plans to buy one. So it would have been nice to know that my laptop would be ready for use. But the lady told me it was ready in the office. That being said, how I found out I was paying $8.99 on a rental, $5 of this was taken out of my savings!
#
# I think to say I'd recommend this place to a friend. If you want a business, go find the one. I think it'll be a fantastic rate. And it will even take you a few days to find it online. My rental looks great, too. And I'd even recommend buying a new laptop and doing this!
#
# *UPDATE*
#
# Well my laptop is ready, and it looks new and super shiny. I did this as well, and it's still the same size. Plus, it's super comfortable, and I think I like that!!<|endoftext|>
# <|startoftext|>So far I have tried the coconut coconut shrimp and it's delicious. It seems like the shrimp is a "chef's cut up" to give it a really good texture when you mix all the other tasty foods.  For sure it will bring those around here. The shrimp was fresh with a perfect ratio of toppings so those are my favs.  The portions are generous. They also have a lot of people standing around. No matter what restaurant they are in.  I love how the tables are laid out too. It adds a nice touch.  When I was in a restaurant it felt like the chairs would be under your skin. The people making orders here are attentive and have more than enough attention. They will always be coming back out the line.  This is a great place to try and you'll leave with a newbie.<|endoftext|>
# <|startoftext|>The food is extremely good. I always go to the newest location. It's always hot inside. I would not give up the new one if I lived in Phoenix. It's worth it!<|endoftext|>
# <|startoftext|>I am not very familiar with Chinese food, but I've been going there for years now and am always greeted with a smile and an excellent dining experience. I love it!
#
# I go here for lunch and dinner, and when I have room, I also try to find a quick bite to eat at lunch/dinner. And I think when you sit down, the space is just right -- so you get to the spot.
#
# I've tried all the dishes on the menu (but my favorite so far
#
# [3205 | 4941.07] loss=3.09 avg=3.03
# [3210 | 5027.85] loss=2.88 avg=3.03
# [3215 | 5113.54] loss=3.28 avg=3.04
# [3220 | 5198.56] loss=2.92 avg=3.03
# [3225 | 5284.77] loss=2.95 avg=3.03
# [3230 | 5370.13] loss=3.18 avg=3.03
# [3235 | 5455.07] loss=2.87 avg=3.03
# [3240 | 5540.19] loss=3.16 avg=3.03
# [3245 | 5625.81] loss=2.59 avg=3.02
# [3250 | 5711.15] loss=3.09 avg=3.02
# [3255 | 5795.68] loss=3.06 avg=3.02
# [3260 | 5881.29] loss=3.20 avg=3.03
# [3265 | 5966.93] loss=3.09 avg=3.03
# [3270 | 6053.97] loss=2.98 avg=3.03
# [3275 | 6141.02] loss=3.11 avg=3.03
# [3280 | 6228.67] loss=3.09 avg=3.03
# [3285 | 6314.71] loss=2.89 avg=3.03
# [3290 | 6400.83] loss=3.57 avg=3.04
# [3295 | 6486.84] loss=3.25 avg=3.05
# [3300 | 6573.09] loss=3.24 avg=3.05
# ======== SAMPLE 1 ========
#  vant les gens le sèche d'aliment les bécois et le plus légités de la rue.
#
# C'est la peine sur la lerie du jour, les fis la derniée, les bécois de mon élément. On ce que jessuvais aussi, la peine et la peine au jasse et le resto, le monde élu pour mien t'eau de un télévrière de la tarte.
#
# Le monde régulière, le fera à t'ampli.
#
# The place was extremely busy but we weren't the first people working. After a while, our waitress came by to check up on us and saw the chef behind the bar who's been cooking everything. He saw what I was having and promptly brought me a bottle of water for my tarte, and introduced himself and asked me about the night previous, and if I'd be having another meal.
#
# I asked him how he knew what was fresh. He mentioned to me that he's been at Paris (Paris) since August; so I guess he knows the ingredients of the day's meal just fine. That evening, I was sitting in the bar and saw a lot of people sitting in the dining room. This is a great thing when you're looking for some good French food! I was excited and happy at the same time, but I had to choose where to sit. I didn't feel rushed or intimidated when I had to choose.
#
# My tarte came out beautifully and was light and fluffy, but I'll try to do the best I can as its taste is what I love to do with food. The chef's wife was cooking on the side; I was the second to order, so after a couple minutes, the waitress brought our orders over. That lady was extremely attentive.
#
# All I'd say is that we would come back to this restaurant again - the food is really good and very affordable<|endoftext|>
# <|startoftext|>I was going to review this place because their customer service is not the best but it is a great price and service was fantastic. We got the "Hot Air", and we had it at $25 a pop for 6 pieces. They were not too crispy like I prefer. We were just blown away in how the food came out. The only complaint about the service is that it was a bit more salty. It could have been the owner but all the flavors were great. In the end I'm definitely in love with this place<|endoftext|>
# <|startoftext|>I recently moved out and needed my eyes checked at the DMV.  My eyes were closed as a medical assistant at the DMV told me this exam would go by longer than four hours so I had to do it myself.  I made a few calls and called a few other places but I found my eye doctor and my name was taken.  This is the kind of place that I will only use if my eyes are in good health.<|endoftext|>
# <|startoftext|>I would recommend all of these restaurants to anyone looking for a memorable experience.
#
# I had an Italian in Las Vegas that I wanted to impress at dinner and this was the restaurant I chose. After searching on yelp, the food and service was one of the favorites on Yelp (with a little Yelp community help)
#
# The menu was on point: I wanted the chef's table to be on point, with a few drinks for me to look at (the owner's had recommended 3 different spots and these three spots were the best ones by far!), and with the service to top it off.
#
# My dinner was perfect: The wine list was off-the-chart and fresh and my friends and I enjoyed some killer drinks in their cocktail menu.  Our server who helped us through was personable, friendly, and a perfectionist with the cocktail menu. My personal favorite cocktail was the black cod. It was so perfect with just a touch of sweetness on the side.
#
# The staff was also friendly, attentive and friendly, despite their short notice. The food menu is a variety of options that I found out later.  The prices are really expensive but you get amazing value for your price. This has to come to the table because I knew I could get a special experience with great food and great value.
#
# The food: I got the Caesar (or the Caesar as I like to call it: the Caesar as we call it) with chicken. I have been getting this dish for years. It came in a small sauce and it had very little of a kick but was just good quality and good flavor.
#
# The Caesar was delicious but I wish it had a bit of the meat taste, maybe a little heat, or as I
#
# [3305 | 7007.78] loss=3.35 avg=3.06
# [3310 | 7091.16] loss=2.72 avg=3.05
# [3315 | 7176.04] loss=3.01 avg=3.05
# [3320 | 7261.10] loss=2.95 avg=3.05
# [3325 | 7344.70] loss=2.94 avg=3.04
# [3330 | 7427.99] loss=3.25 avg=3.05
# [3335 | 7511.60] loss=3.07 avg=3.05
# [3340 | 7595.07] loss=3.13 avg=3.05
# [3345 | 7678.39] loss=3.08 avg=3.05
# [3350 | 7762.73] loss=3.12 avg=3.05
# [3355 | 7845.65] loss=2.76 avg=3.05
# [3360 | 7928.19] loss=3.03 avg=3.05
# [3365 | 8011.42] loss=2.65 avg=3.04
# [3370 | 8095.14] loss=3.48 avg=3.05
# [3375 | 8178.83] loss=3.60 avg=3.06
# [3380 | 8262.36] loss=3.33 avg=3.06
# [3385 | 8345.82] loss=3.23 avg=3.07
# [3390 | 8429.75] loss=2.83 avg=3.06
# [3395 | 8513.45] loss=3.06 avg=3.06
# [3400 | 8596.96] loss=2.98 avg=3.06
# ======== SAMPLE 1 ========
#  Keak and let them taste...what more could you ask for.  They will add a nice crunch while the sauce is still just as tasty.   I got the egg rolls and the duck confit.  I got it cold, they were hot for me.  All were delish, I was so happy to hear that you can call ahead to be served, I got the fried chicken fingers.  The fried chicken fingers was so good, I had a taste, lol...it was a lot better. I can already envision myself having a huge appetite next time, haha.  I recommend not complaining about the parking, you're in a very good area and you are at a different time (it does get a little busy in the afternoon).
#
# All in all, I highly suggest this place, it's really not a bad place.  Great quality meats and good prices and the service is pretty good.<|endoftext|>
# <|startoftext|>The best bar right in Vegas. No I was not talking about the girls in the bar there - not the girls in the bar but the girls behind the drinks.
#
# It was a great bar, the girl bartenders were super nice. I am a new patron so I was a little nervous. I tried drinking and going all drinks and it was so easy! The bar is very clean and the place is nice and pretty too - lots of bar seating. It was pretty cool in there. I went early on a Wednesday and loved it. Will definitely be back. I always look forward to making more drinks.
#
# You can never go wrong here especially after the price from the bar is so good.<|endoftext|>
# <|startoftext|>When choosing your dog of choice, there is no need to worry about cost - all the staff here are great! I have taken my dogs on many rides as well and none have ever left a bad impression! A quick one-stop shop to pick them up.
#
# My dog was a bit nervous to be picked up, so they gave a bit of the dogs leash when they arrived to meet and greet. You are asked if there is any discomfort or discomfort in having to leave a collar or leash on while picking up your dog. And then they take you into a separate room in the back of the hotel - it's a nice place to wait while your dog is sleeping.
#
# I'm personally very happy with this facility - they always use only the good stuff and I've seen no need to buy any other drugs, unless the vet does sell pills or they charge a bit for it.
#
# You can also pick up your dog online and they get him registered at the venue on site for free.
#
# My dog is a bit scared to say it, so I've recommended that only she will be able to pick him up before I can get them back and take them back to a room for more testing.<|endoftext|>
# <|startoftext|>After moving out of state for a year, my dog is the only pure animal in my family that needs a full service training program - I have been a trainer for years and always knew I could be ready to go again the next day. As soon as I called to check the schedule I was warmly welcome by the whole staff. The training team and trainers are very experienced and trained highly. The classes can be difficult for dogs that have a tough time adjusting. They have classes for all age range and age group and I have never had such a helpful, supportive, and amazing trainer. At the end we even got a class called "Get Dog" for my pup, and the teacher actually taught us. My pup and I worked hard for the next few months (but not any where near the end). The training is so intense, and they keep our dog learning for a LONG time!
#
# They always help their dog with whatever the issue (if any) is. The training is fun, and they are fun and upbeat and encouraging to our dog to go. We've also met several trainers and coaches to work with our pup and we have shared a lot, none of which are in your area.<|endoftext|>
# <|startoftext|>This is one great place. Great food, always very full, and a lot of fun.
#
# My wife and I went there about 2-3x a week when they were new and had a smaller menu but they were just as delicious when I was with them while eating them lol. When we got around to checking out the menu we were blown away - I was so happy to see that I wanted to eat here again. The menu is full of unique options so I didn't feel like I was eating a greasy, overpriced, over priced, food coma-inducing crap eating buffet.
#
# I am looking back at my wife's review - she actually did give us this review for the food
#
# [3405 | 9037.53] loss=3.00 avg=3.06
# [3410 | 9121.95] loss=3.32 avg=3.06
# [3415 | 9206.04] loss=2.70 avg=3.06
# [3420 | 9288.95] loss=2.84 avg=3.05
# [3425 | 9374.19] loss=3.32 avg=3.06
# [3430 | 9458.84] loss=2.48 avg=3.05
# [3435 | 9544.17] loss=3.02 avg=3.05
# [3440 | 9629.50] loss=3.05 avg=3.05
# [3445 | 9714.14] loss=2.78 avg=3.04
# [3450 | 9797.96] loss=2.90 avg=3.04
# [3455 | 9882.14] loss=3.35 avg=3.05
# [3460 | 9966.41] loss=2.83 avg=3.04
# [3465 | 10050.57] loss=2.84 avg=3.04
# [3470 | 10134.47] loss=3.00 avg=3.04
# [3475 | 10218.35] loss=3.17 avg=3.04
# [3480 | 10303.30] loss=3.06 avg=3.04
# [3485 | 10386.46] loss=3.15 avg=3.04
# [3490 | 10469.70] loss=3.16 avg=3.04
# [3495 | 10553.68] loss=3.01 avg=3.04
# [3500 | 10638.11] loss=3.28 avg=3.05
# ======== SAMPLE 1 ========
# . It's literally the best place. Seriously, go at least once, you won't be disappointed.<|endoftext|>
# <|startoftext|>I love this place. My husband and I have been going since the beginning. They do not try to up sell on features. I find that they use their resources wisely. They have a new place in the parking lot!<|endoftext|>
# <|startoftext|>I am writing this as I sit on the street in Phoenix, just across the street from the old location of the place. It is amazing that we have yet to find a place on which we both like better (in a big way)! This is a good time to check it out and give it a try; you'll be glad you did!
#
# The prices are fair. It does get hot and spicy, so the menu does have a few more things that I have noticed in the past few years, though I have no idea what they are. The service is always friendly.
#
# This place is pretty clean, as that is really something most restaurants fail to do.  Their front windows are open, as one might expect, so you may be open to the street, which can be quite pleasant.
#
# I have tried their new spots, but also tried their old ones, and I am now in Vegas visiting from New York (a very nice city!), so we have to come back here frequently.
#
# I would definitely recommend bringing your date (or a coworker with whom you are going to be having intimate) here to do something special. They do have some private area in the kitchen as well as the dining area (only opened for the dining and non-dining public). This is also nice, especially since it is a bit more intimate, where you can see into the dining area as well as the bar.
#
# The restaurant is well lit in the restaurant, and there is plenty of room to talk to others around you. It is not very busy, and the staff is friendly, efficient and a pleasure to talk to. (If at 6, it is good, if it is just a "bad" day, it isn't so bad...)
#
# I think the only reason to go is if you like food; if you like to eat well and are willing to wait for it; if you are willing to talk about it and want it all to come together; if you are willing to pay a small amount for a good restaurant; or if you like to see someone else eat better and the rest eat better and the service of course does.  This is not a place for people who like to eat healthy and healthy options, and eat healthy and healthy options while drinking a glass of water; it is much less about the food than the quality, as well as the environment.
#
# My favorite place is this place! It is not close to home, and it is so good that it is worth paying a little more per person for that meal.   No matter who I ask, no matter what side of meat I order (or do not order), I always opt for this place!<|endoftext|>
# <|startoftext|>This place does everything right: it's cheap, it is delish, it has a nice little bar on the corner, and it is clean. I had the fried green tomato salad (made it the way I like my tomatoes) and the pork chop which was also excellent. The fish taco with a sashimi was also very tasty. We will definitely be taking our families here.<|endoftext|>
# <|startoftext|>These guys are awesome.  Had the best time ever! My car needed some serious attention.  The staff was great! They took some time and truly answered any questions and provided excellent service to get the vehicle we needed, even though there were a couple of items ordered I didn't know I needed. The whole time I was there, the staff was amazing and treated my car like gold.
#
# Would definitely come here for any dealership needs.<|endoftext|>
# <|startoftext|>Came here when they first started taking walk-ins and I couldn't have been more pleased with the customer service and professional service they offered. It was a huge help! I would recommend to anyone I visit. You won't be disappointed!<|endoftext|>
# <|startoftext|>I've been coming to the gym as a client for about 6 months now, and this place is close to perfect! The gym owner, Nick, has really worked at getting the gym moving out of the location on the street in the past year or a year, and he has done the job. If anyone wants to work on a gym, gym membership at the time of this writing is still free.  I don't find the gym membership option much to bother me except for the
#
# [3505 | 11070.80] loss=3.04 avg=3.05
# [3510 | 11153.61] loss=2.65 avg=3.04
# [3515 | 11237.71] loss=3.19 avg=3.04
# [3520 | 11322.88] loss=3.47 avg=3.05
# [3525 | 11406.67] loss=3.38 avg=3.06
# [3530 | 11491.25] loss=2.81 avg=3.05
# [3535 | 11574.58] loss=3.12 avg=3.05
# [3540 | 11658.67] loss=2.88 avg=3.05
# [3545 | 11741.28] loss=3.07 avg=3.05
# [3550 | 11825.67] loss=3.26 avg=3.05
# [3555 | 11910.11] loss=3.19 avg=3.06
# [3560 | 11993.62] loss=3.32 avg=3.06
# [3565 | 12075.97] loss=3.11 avg=3.06
# [3570 | 12159.82] loss=2.94 avg=3.06
# [3575 | 12242.63] loss=2.68 avg=3.05
# [3580 | 12325.31] loss=2.75 avg=3.05
# [3585 | 12407.94] loss=2.98 avg=3.05
# [3590 | 12493.71] loss=2.83 avg=3.04
# [3595 | 12577.39] loss=3.01 avg=3.04
# [3600 | 12659.77] loss=2.89 avg=3.04
# ======== SAMPLE 1 ========
#  joint.  They have a great atmosphere too though.
#
# The staff were so friendly and friendly!!!<|endoftext|>
# <|startoftext|>I am a New Yorker who came here with the husband a few months ago to celebrate his birthday. I am from Cali so I have been sooo lucky on getting a restaurant that serves food that tastes the way they do in NY! I'm not a big steak eater so we decided to come early.
#
# We got the steak, the beef short ribs, and steak. All 3 were delicious! The steak was tender, meaty and juicy to boot. The beef short ribs were tender, the taste of steaks is amazing! Our waitress was Alyssa and she knew the steak. We'll be back!<|endoftext|>
# <|startoftext|>If you're looking for a place you can call home that serves delicious Indian food, look no further!
#
# Our waitress was Amanda and she was great.  She introduced herself to us at the beginning of our meal, then got to us, introduced us to her as one of the owners and worked tirelessly to make sure everything was fine.  After that came about, they introduced us to the owners who were in the lobby.
#
# They have a great selection of fresh veggies with amazing presentation and amazing flavors.  You can tell they work hard while serving you.
#
# Everything tasted better as we were in deep conversation with them.
#
# The food was delicious - I would highly recommend the place to anyone looking for a great tasting Indian restaurant (and it really is delicious!)<|endoftext|>
# <|startoftext|>Crispy on the outside and crispy on the inside.  You can tell the owner doesn't take a lot of pride in his business that shows up on his exterior.
#
# I've been to their menu twice and there's a huge selection to choose from.
#
# On the other hand, most of the food comes with a little bit of seasoning when it comes to taste..
#
#
#
# I usually bring friends here and I've never found a bad meal.
#
# I also recommend the bibimbap too.  The spicy kick was good and the chicken was also good.
#
# The last time I was there was last week and they did a huge reno.  I thought it was the owner's way out just waiting for people to come back!
#
# It's not too far from us and the food is amazing!<|endoftext|>
# <|startoftext|>The food here is the BEST. The food is hand crafted to order and the staff is very friendly. They bring so much variety of goodies like pretzels, kiwis, stuffed peppers and cucumbers and of course they bring you some fresh yogurt.
#
# In my opinion the chicken is well thought out and the sauce really makes them special.<|endoftext|>
# <|startoftext|>My friend and I went to the grand opening party from 7am to 8am at Soho Burger.
#
# It was just as good as it is for the prices there. We had a good quantity of dishes, a wide variety  of toppings, and a good amount of protein items. The food was all reasonably priced too, even with a 5oz beef and 8oz salmon. The salmon alone is enough to feed two people for the entire night.  The burgers are HUGE and generous with toppings and a variety of toppings. We had some other entrees and I would say a third was $6.
#
# They have a lot of local food on the menu to choose from as well, like the chef's special kimchi soup, and spicy fried okra.
#
# I did not get a chance to eat there but the food was great.  Service was attentive and friendly, and the food was delicious.  If you are in the neighborhood, definitely give it a shot. It's worth the $$.<|endoftext|>
# <|startoftext|>I've been to a lot of festivals in Vegas in recent years and I've been to a few of them. This weekend, I saw the second Friday night of the year. One of those has to be the first one last weekend.
#
# Sitting in the bar, I decided to take a bite of the appetizer to see if it was good. And yes it was. The oysters, crab cakes with butter and lemon, the crab cakes with the butter, bacon, scrambled and fried potatoes, and the bread pudding with butter. Wowz... It was all excellent.
#
# We did enjoy the oysters, crab cakes, biscuits w/ gravy, crab cake, crab cakes, bread pudding and bread pudding. The oysters were good, but the biscuits w/ gravy was bland. A bit dry to me, but the gravy had
#
# [3605 | 13096.06] loss=2.92 avg=3.04
# [3610 | 13180.34] loss=3.18 avg=3.04
# [3615 | 13264.15] loss=3.40 avg=3.05
# [3620 | 13348.47] loss=3.12 avg=3.05
# [3625 | 13434.03] loss=3.08 avg=3.05
# [3630 | 13517.39] loss=2.67 avg=3.04
# [3635 | 13600.13] loss=2.94 avg=3.04
# [3640 | 13684.99] loss=2.15 avg=3.03
# [3645 | 13770.07] loss=3.55 avg=3.04
# [3650 | 13853.21] loss=3.12 avg=3.04
# [3655 | 13936.64] loss=2.51 avg=3.03
# [3660 | 14021.03] loss=2.72 avg=3.03
# [3665 | 14104.52] loss=2.80 avg=3.02
# [3670 | 14186.81] loss=2.87 avg=3.02
# [3675 | 14270.42] loss=3.00 avg=3.02
# [3680 | 14354.24] loss=3.08 avg=3.02
# [3685 | 14436.70] loss=2.79 avg=3.02
# [3690 | 14519.42] loss=2.91 avg=3.02
# [3695 | 14603.17] loss=2.64 avg=3.01
# [3700 | 14688.18] loss=3.26 avg=3.02
# ======== SAMPLE 1 ========
#  combination. All of the people on my staff were very helpful to every customer we had. The prices were reasonable and the workers were friendly. I definitely think this clinic is one of the best for my family.<|endoftext|>
# <|startoftext|>I love the food from Here and there is no bad news!
#
# Now this is one of those restaurant you could go to over and over again. There are just some things about the Food Network that make you feel special and special each visit. The food, the atmosphere, the service, the location, all I can say is everything I was impressed with!
#
# With five and a half stars I want to break that, but don't want to end at five!<|endoftext|>
# <|startoftext|>There are a lot of fun things going on inside and out of the city and no one knows that this place has a huge wine and beer selection!
#
# You should make a point of going. It is well worth the drive and all of the fun you're in for!<|endoftext|>
# <|startoftext|>Dr. Muthier is an excellent dentist. His staff is truly caring , very efficient, and is able to find solutions to a problem for that which a little uncomfortable to go to someone you know you don't have a good eye doctor for a few years now.<|endoftext|>
# <|startoftext|>I was recently in town visiting my family.  I was able to stop in to see Dr. Muthier.  She offered me a consultation about my dog.  I needed to see Dr. Muthier for my dogs .  She put on the best show on television.  In no other hospital I would say.<|endoftext|>
# <|startoftext|>I am a big fan of Chocolatier!  I am an old school cheesecake fan, so Chocolatier is a welcome welcome treat in the new location.  I was pleased to see that they included an assortment of cheesecakes, including the famous cookie cup.  They didn't cut up any cookies and they included about 4 layers of fresh chocolate cake for the small cup.  I can't remember the names of the various cheesecakes, but I enjoyed the flavor of each one.  The cookies were a good size, just not what I'd get from a chocolatier.  It is worth noting that the chocolate cake is extremely rich, which is a common concern of mine.  It is also included in the standard cheesecake that is offered here.  They also offer a daily option when purchasing one of their daily cheesecakes, which includes a chocolate ice cream or a fresh fruit roll.  They also offer a special from the daily chocolate chocolate cup, a chocolate cake with a scoop of chocolate ice cream on top of a plain cake, and an additional cup of ice cream and the two cheesecakes are available.  I just got another cup of the coffee ice cream with fresh fruit, ice cream, and vanilla ice cream, and this is my new favorite chocolate cup of all the cheesecakes.  My favorite part is the fresh strawberries sandwiched in, which I enjoy at the end of a cheesecake cup.  If you like your cheesecake to be thick, you might want to just order it in a cup or with a spoon.  The only negative thing is that there's no coffee in here to sip and savor.  I'd rather just order it fresh and enjoy the chocolate.  I can't wait for next time!<|endoftext|>
# <|startoftext|>After going around the city for the last few years it was time to start my little dog grooming.  I was referred to Dr. Fick by a friend whom had found a very good place on Yelp and in addition to being highly recommended by my friend and dog lover I was also referred to Dr. Fick from start to finish.  My dog was a young pup with many health issues, was fearful and extremely anxious.  My dog was only 13 months old and was a wild man.   He was scared of me, my two children, and the fact that the area was full of people who were walking him when he was around.
# After a short phone call to Dr. Fick and the office he came out and went through with my dog.  He took his time with our dog with my dog and made sure our dog had food and water when necessary. Within 2 weeks our dog was no longer fearful of anyone - he had learned to walk.  He was able to find food after the initial training without needing to ask.  He was in and out in 10 days with our dog!   He walked like a new normal dog, went through a training class, which was all about training, and we were thrilled with his progress over the past
#
# [3705 | 15113.95] loss=2.74 avg=3.01
# [3710 | 15192.01] loss=2.99 avg=3.01
# [3715 | 15269.40] loss=2.62 avg=3.01
# [3720 | 15345.65] loss=2.97 avg=3.01
# [3725 | 15422.60] loss=3.35 avg=3.01
# [3730 | 15500.26] loss=3.20 avg=3.01
# [3735 | 15578.17] loss=3.14 avg=3.01
# [3740 | 15654.77] loss=3.08 avg=3.01
# [3745 | 15731.29] loss=2.83 avg=3.01
# [3750 | 15808.22] loss=3.23 avg=3.02
# [3755 | 15886.12] loss=2.98 avg=3.01
# [3760 | 15962.60] loss=3.31 avg=3.02
# [3765 | 16039.03] loss=3.20 avg=3.02
# [3770 | 16117.22] loss=2.98 avg=3.02
# [3775 | 16194.55] loss=3.06 avg=3.02
# [3780 | 16271.11] loss=2.79 avg=3.02
# [3785 | 16347.29] loss=2.81 avg=3.02
# [3790 | 16424.07] loss=2.50 avg=3.01
# [3795 | 16501.32] loss=3.12 avg=3.01
# [3800 | 16577.33] loss=3.01 avg=3.01
# ======== SAMPLE 1 ========
#  I would come back.<|endoftext|>
# <|startoftext|>I think that my first Yelp Event was just a few months ago and then it's just now starting. I'm very excited I just got around to Las Vegas this week for the first Yelp Event I've been coming here since I was a little boy on Christmas Eve 2014 and I had to come here on both days but this week was the first day that the food festival is set aside, I just saw what I wanted to see so I wanted to get a taste of everything that they offered in the food and drink area for all to see and enjoy.
#
# I'm glad it's the Food Festival because it allowed the Chef to come out and talk about everything and the things I want to learn about in food production. He had a few really cool events going on in the food area and the menu and beer offerings is amazing on the food. We sampled a number of things, and it's amazing. It was the perfect place to bring a group or date night with some friends. I would've liked to check something out and have them try a few of the food items on the food menu because I loved it and just wanted to try as many new items the Food Festival made available.
#
# So we made our way out and we made it through the "Food, Beer, and Food Festival" with the Chef to talk about how food, processes and equipment, and how he uses "local" ingredients. My friends and I went and we loved it and we will be coming back and trying some of the other things on the menu for sure. The beer menu is a huge offering, I've never had that one before so it was great to try and see which ones that are featured on the menu and who was featured on the list.
#
# The owner of the restaurant and the event planner were both extremely helpful and very friendly and we had a great time!<|endoftext|>
# <|startoftext|>Havocados is the best in town with their service and selection of smoothies. I've used most of the flavors on some of them they have... some are my favorite flavors. My go-to is the avocado avocado and the strawberry/guacamole smoothie. The owners are incredibly nice and helpful. It's like a family run business. I'm glad I'm in AZ!<|endoftext|>
# <|startoftext|>If you haven't already been here, come here!  After trying a couple of places that I didn't know anything about, this place changed my life.  The best coffee in town.  The food itself made me want to have the best coffee ever.   This place is the best and the prices are affordable.
#
# It's the small town square in The District, or the District area.  Their menu is huge so it's hard to choose.  The staff is super friendly and helpful.  They will be happy to help you out.   The food is great and the coffee is great.
#
# You're getting it here and don't tell anyone.  I'll be the first to tell you that if you are the perfect date night, this is where my boyfriend and I go.
#
# You can also check out their Twitter accounts.  I was a fan of their chocolate peanut butter chocolate peanut butter bars.    <|endoftext|>
# <|startoftext|>This is the best food I've ever had in my life.  I don't know why there are negative reviews here.  As for the food I had, it was excellent - perfectly cooked, full of flavor, and the price was excellent.
#
# I was very surprised with how delicious the service was and I will definitely be back again.<|endoftext|>
# <|startoftext|>This place is amazing.  I had the best dinner with my dad since my mom passed and we stayed here. It is clean and classy, and the food was extremely delicious. We split the lamb skewers, a lamb burger with cheese burger, fries, and onion rings - everything on this burger were sooo good. A little pricey but so worth every penny. The lamb steak is excellent. They make it with real beef and it was really good. I also tried the fried calamari (my fiance's favorite - it was perfectly cooked and was good) and was very satisfied.  They even had an amuse bouche that I was very pleased with.
#
# My only gripe was, the wait wasn't quite as quick as I'd like. But it was worth it (it's not busy that weekend).  The other side dishes were nice. And the dessert menu was delicious.  The ice cream, with chocolate chip cookie was great!
#
# My only criticism is that there wasn't a large variety of different types of meat options for
#
# [3805 | 17010.59] loss=2.81 avg=3.01
# [3810 | 17095.32] loss=2.94 avg=3.01
# [3815 | 17177.83] loss=2.26 avg=3.00
# [3820 | 17261.05] loss=3.03 avg=3.00
# [3825 | 17345.10] loss=3.13 avg=3.00
# [3830 | 17428.22] loss=2.93 avg=3.00
# [3835 | 17511.49] loss=3.05 avg=3.00
# [3840 | 17594.61] loss=2.80 avg=3.00
# [3845 | 17678.11] loss=3.10 avg=3.00
# [3850 | 17762.54] loss=2.94 avg=3.00
# [3855 | 17845.66] loss=2.68 avg=2.99
# [3860 | 17929.92] loss=2.99 avg=2.99
# [3865 | 18013.05] loss=2.77 avg=2.99
# [3870 | 18096.84] loss=2.88 avg=2.99
# [3875 | 18179.56] loss=3.03 avg=2.99
# [3880 | 18263.58] loss=3.11 avg=2.99
# [3885 | 18348.32] loss=3.32 avg=3.00
# [3890 | 18430.64] loss=3.22 avg=3.00
# [3895 | 18513.80] loss=3.11 avg=3.00
# [3900 | 18596.28] loss=2.84 avg=3.00
# ======== SAMPLE 1 ========
#  and don't wear a bra. This store is great!<|endoftext|>
# <|startoftext|>So glad I stopped by, had a free appt. and was pleasantly surprised to find it here in the Valley!
#
# The place was very professional. The sales associate was very nice and had no pressure, very knowledgable about the products, and very patient asking if I had ever heard of this store before, and yes I had! Great job! Great place to get many more goodies! I will be back the next time I am in the valley.
#
# I cannot wait to come back and try out all the other items they have on the menu!<|endoftext|>
# <|startoftext|>I am new to writing reviews and I came in with a long list of questions about the spa and I wasn't sure if I had just stumbled upon a spa. I was looking for a place close to home, just a little more private, and close to me, and this place has all the amenities I look for in a spa, including showers, bath products, and towels.
#
# We started with the cold room, which had an actual toilet with the cleanest paper towel. Very clean and sanitary, and in line with the hot room (since I was in the hot room). Then we moved on to the dry sauna. I guess the towel itself is the best thing, but what was still in the cold room was the towels, and I was a little peeved at how I had to wipe my hands all over my hands and the bathroom.
#
# When we got back the hot room I was soooo happy! I loved the hot room, its just as cold as the main room, and has a different shower counter to hold a toilet, bath, and even a shower water dispenser to empty your dirty hands in. Also I love the shower tub! It was warm and had a fan that could handle the showers.
#
# The hot room had so much water so I went again with hot and cold towels on the towel.
#
# I was not bothered or asked anything (although I did mention the toilet was clean.) The hot room had soap, soap, and laundry detergent for you to wash your hands in and a full changing room. Also had a shower for you to have some room for your clothes.
#
# The dry sauna was one of the most fun to walk in, and it looked even better. The soap here is great and the soap was a bit spicy, but still perfect for me. It was also more expensive than I thought.
#
# The hot room was also super clean. The soap and vinegar were great (they have really good hot and cold sands right now,) but I have never had soap that wasn't the best.
#
# The hot room had shampoo, conditioner, body wash, conditioner, and hand wash. I was really pleased, especially after having the water changed after each use.
#
# ...
#
# Oh, but if you're a sushi fan like me, make sure you give the chef a try: he gives you all the fish you ordered, and adds fish to any of the sushi rolls (with little sauce) to make it more appetizing, like some sushi places do.
#
# When you're a sushi eater, this place is the best, but if you want to skip all the other fish-drunken sushi shows, the chef is awesome, too.<|endoftext|>
# <|startoftext|>This is an amazing place to take a relaxing break.  They give you one hour massage, followed by another hour or so of a special massage (whichever you wish).  The price is reasonable; you get a little room to move around if you have questions.  And I never feel overwhelmed in the way when I'm getting up.
# What the hell, it's true; this is one of my favorite spots out in the city.  It's not a traditional spa - they
#
# [4705 | 35832.52] loss=2.94 avg=2.98
# [4710 | 35919.82] loss=3.02 avg=2.98
# [4715 | 36007.49] loss=2.99 avg=2.98
# [4720 | 36095.89] loss=2.92 avg=2.98
# [4725 | 36182.77] loss=3.18 avg=2.98
# [4730 | 36271.36] loss=2.90 avg=2.98
# [4735 | 36358.58] loss=3.40 avg=2.99
# [4740 | 36446.51] loss=3.16 avg=2.99
# [4745 | 36533.39] loss=3.11 avg=2.99
# [4750 | 36622.82] loss=2.65 avg=2.99
# [4755 | 36711.41] loss=3.02 avg=2.99
# [4760 | 36798.55] loss=3.04 avg=2.99
# [4765 | 36885.59] loss=2.88 avg=2.99
# [4770 | 36973.38] loss=2.57 avg=2.98
# [4775 | 37061.38] loss=2.75 avg=2.98
# [4780 | 37148.98] loss=2.72 avg=2.98
# [4785 | 37236.42] loss=2.86 avg=2.98
# [4790 | 37323.36] loss=2.95 avg=2.98
# [4795 | 37411.12] loss=3.13 avg=2.98
# [4800 | 37498.31] loss=3.17 avg=2.98
# ======== SAMPLE 1 ========
#  etc!!
#
# This is not your typical sushi restaurant. The restaurant/bar setup here are designed so well. I am super happy that they took the sushi ball from some other restaurant and added more modern decor to the restaurant, instead of putting more plastic and cardboard over the top. Now, for me, it's much better. The food is so fresh, seasoned to perfection, and the sushi is not too salty like some places.
#
# In addition, the prices here are just right for some of the sushi. Most restaurants charge an outrageous premium for their top notch sushi, so I do not expect much at all at this new one.
#
# Oh, and as if all that wasn't enough, the service was also great. They were very accommodating and very knowledgeable about the menu changes made by the sushi chef.
#
# A true pleasure meal in Vegas for just about any meal.<|endoftext|>
# <|startoftext|>I have nothing but good things to say about this dealership. Every single time I bring in my car, the folks at Toni Autos have come over to help me out.  From service, to work, things have always been done right. A couple of years ago the dealership had to run up the block to grab my vehicle.  When I brought it in for an emergency drop off, they had a small mess waiting to get into the car.   No big deal because they are very honest in what they do in the service department, and I have had that happen many times.
#
# A decade ago I had a Honda Civic that would not start the shift, which the mechanic had told me I had no clue what to do.  When the car started running again at about 1:30 the next day, he gave me a discount on the next drop off.  He was very honest on what had happened and advised me to come in and have the car examined.  I did exactly what I needed to do and the service guy took her time looking to know exactly what the issue was.   The Honda was running perfectly when I picked it on the way to work but when I picked it up the day the appointment, my transmission and brakes started to go flat out.  A couple of days after the car, my Honda started running in the same way as it had when the shop dropped off Honda.  It was a flat out, not a stalled out, in the rain.  The maintenance guy said the car stalled out, but that he had no idea what had happened.  He said he had no knowledge of what had happened but he could have checked the car himself.  This is not a mechanic that gives you a discount on his work since it does not start the shift while you drive through the turn.
#
# I did as I needed to do, which wasn't a fault of the car.   The service manager said her engine was being messed up again.  She checked it out like it was nothing to worry about.  She explained things to me that I could not have done myself.  I told her I had a big issue with my Honda, but I wanted her to run a very thorough diagnostic on some more important questions.  She didn't try to run tests on the other parts since she knew the issue, and she explained why she ran those tests in the first place.  She gave me a full tune up on my entire car, and then it was time to do the tune up.  She took the time to spend a couple minutes on the radio talking to the crew that had worked on the car when they dropped off it that day.  She told them about my car, and they showed her the problem when it was first placed back in the shop.    They fixed a loose tire that no one could figure out on their first guess.  She gave me a discount on the repair.  They explained that they would have to change the tire out, but they could have the repair done in about an hour.  After he fixed the tire, the service manager came out to see if the tire was a "regular tire.  I told them that my Honda was a $300 and it would be about $400.  They said that it would be about two days to get it back out, but they could have it back out by 2 a week.  One week.  So they said they could have the tire out in that week for a check-up.  That was exactly what she told me.  I brought the car in for a check-up and asked her to drive the tire back in.   I told my mechanic a couple of times what had happened, but he said he'd have to fix it the next two days.   Now, my Honda stopped running at that point.   The tire had been fixed, so then when she told me that it was done, he said she could pick up the tire that they replaced.  She told me it would
#
# [4805 | 37946.08] loss=2.93 avg=2.98
# [4810 | 38034.58] loss=2.16 avg=2.97
# [4815 | 38123.36] loss=3.22 avg=2.97
# [4820 | 38210.99] loss=2.72 avg=2.97
# [4825 | 38298.91] loss=3.08 avg=2.97
# [4830 | 38387.14] loss=2.92 avg=2.97
# [4835 | 38475.45] loss=2.98 avg=2.97
# [4840 | 38562.08] loss=1.40 avg=2.96
# [4845 | 38650.08] loss=3.04 avg=2.96
# [4850 | 38737.59] loss=2.94 avg=2.96
# [4855 | 38825.32] loss=3.07 avg=2.96
# [4860 | 38915.34] loss=3.09 avg=2.96
# [4865 | 39004.59] loss=3.09 avg=2.96
# [4870 | 39093.98] loss=2.95 avg=2.96
# [4875 | 39183.11] loss=3.27 avg=2.96
# [4880 | 39271.83] loss=2.90 avg=2.96
# [4885 | 39360.83] loss=2.83 avg=2.96
# [4890 | 39448.76] loss=3.08 avg=2.96
# [4895 | 39537.14] loss=3.08 avg=2.96
# [4900 | 39624.97] loss=3.02 avg=2.96
# ======== SAMPLE 1 ========
#  C Biscuits & Gravy - sooo good, I almost forgot. But it is one of my favourite things right now, so I was pleased!
#
# They still have the famous baked potato (pancakes are my most favourite) on top of the plate, because they are super high quality.<|endoftext|>
# <|startoftext|>I was invited here for a work dinner and since I live in Madison and work in Milwaukee, I have gone to a lot of places in the past that have done a bad job of this restaurant. Here it was just right. It was spotless. It's been years since I've had such nice, friendly service. If the food is a little "tough" to eat, the staff will do their best to make it bearable. For this type of restaurant, it's not the restaurant's fault. There are so many places in town that it's pretty hard to please. There are many places you'll be very disappointed with service, so they won't tell you any secrets.
#
# I don't think they do this to keep you from getting your money's worth. I'll come back to this fine establishment again and I recommend everyone try it.<|endoftext|>
# <|startoftext|>When my husband wanted to pick up a guitar for his family, I went through about 10 different guitar shops. I found this used store on the street where I work, and he went to one who did just as well. She was friendly and answered all of my questions and worries. She gave him a great guitar and gave advice on buying a guitar.
#
# We didn't have any serious problems with the price, and we got a wonderful price at a much more reasonable price.
#
# The store is simple to find. There was one person working, and they were courteous and friendly. They were very kind, patient and really did try to give us the money we were asking for. I would go back to these types of places without reservations.<|endoftext|>
# <|startoftext|>Worst decision I ever made in terms of buying a home. The store should have done the whole process from the beginning with each step. We spent 6 or so months buying our new home. I didn't find this store until I moved the family to the valley, but I thought it was great to know they were so down to earth.  I can't help but get my heart in when it goes down.
#
# If you are in a rush, there is absolutely no reason to leave your keys. It's so important you do not leave your keys anywhere else. I couldn't have done it without him. When I got back to Arizona he gave me a little bag on my back. I had some keys but he was so great!  I wish I would have done this before the next sale closed and I would have done it the proper way he always did it. He took the time to chat with us, give advice, and even had me ask him some questions. He told us all the same things that would have been there if he would have never passed me the keys. He did it right.
#
# I wish I would of thought of it when all this happened to the wrong way. He made good money so he should get credit because he had a lot to learn. I have been to other shops and stores where you have to sign up for a sale like a long term mortgage. Not the case at this shop. He is a great guy and is honest. If you need an honest loaner, he will give you the best quality, lowest rate interest rates anywhere.<|endoftext|>
# <|startoftext|>If you are looking into a good carwash, look no further than Best Car Wash. Every single time that I take a car into Best car wash to wash it (and I do that a LOT), we give the customer a few complimentary samples. The car wash we had was not only the best I have ever taken a car to, but the only time I have ever taken a car to Best Car Wash for the same problem was at the Phoenix area.
#
# Great service!
#
# Wash it all!
#
# I will never use another car wash service or product ever again.
#
# When we have a real issue with a car wash, I know who I'm going to call for a new service or something else done.
#
# Trust me. The service and quality here are the real deal. Don't be fooled by the fact that you think the car wash at Best Car Wash has been washed at other salons, you will be disappointed.
#
# A MUST TRY!<|endoftext|>
# <|startoftext|>I recently tried the hot pot in one of the few of my regular places.  I could not find anywhere to do it correctly.  I took it to the staff
#
# [4905 | 40075.45] loss=2.90 avg=2.96
# [4910 | 40163.83] loss=3.52 avg=2.97
# [4915 | 40251.02] loss=3.09 avg=2.97
# [4920 | 40339.70] loss=3.47 avg=2.98
# [4925 | 40427.03] loss=3.03 avg=2.98
# [4930 | 40516.83] loss=3.16 avg=2.98
# [4935 | 40604.56] loss=2.77 avg=2.98
# [4940 | 40692.64] loss=2.71 avg=2.97
# [4945 | 40781.47] loss=2.85 avg=2.97
# [4950 | 40868.79] loss=3.15 avg=2.97
# [4955 | 40956.59] loss=3.01 avg=2.97
# [4960 | 41044.67] loss=2.88 avg=2.97
# [4965 | 41133.26] loss=2.96 avg=2.97
# [4970 | 41221.02] loss=3.21 avg=2.98
# [4975 | 41309.24] loss=2.98 avg=2.98
# [4980 | 41398.23] loss=3.14 avg=2.98
# [4985 | 41486.65] loss=3.00 avg=2.98
# [4990 | 41574.50] loss=3.20 avg=2.98
# [4995 | 41661.85] loss=2.84 avg=2.98
# [5000 | 41750.93] loss=2.91 avg=2.98
# Saving checkpoint/review_star_5_large/model-5000
# ======== SAMPLE 1 ========
#  is a solid place for a romantic Valentine's dinner!<|endoftext|>
# <|startoftext|>Wow, was super impressed with our wonderful experience at this nail salon. A friend recommended us to this nail salon and we are so glad to have come.<|endoftext|>
# <|startoftext|>You know how when you have a dream night of eating at your favorite buffet, and then you come home to a small box of your favorite bingingan noodle, and your nose starts drooling with that sweet savoriness, with an unctuous, rich aroma from the peanut sauce on top? Well, in the case of "The Bingshu, the chef uses a soy dough wrapper to make the sweet and sour chicken with the sauce. He takes his time with everything and has a great sense of humor. That's what you're supposed to do as they say:
#
# Don't eat on the weekends. (That and I'll see other reviews about this for next time.)
#
# I got the "Hummus Wrap" ($9.50) in a large, bowl with white rice (I have to think a bit more as opposed to the regular version.) and "Beef Wrap" ($8.50) (I know, I'm probably over exaggerating about the beef, but I will say it again: don't try any other stuff on that side of the wrap.)
#
# They cook the chicken to perfection (or close to perfection) with a light bit of lemon and zing from the vinegar in the dressing, which they didn't need - or even need it - for me. They had a choice between the regular rice or the beef wrap. I like the white rice that came with a side of "chicken" sauce.
#
# "The Bingshu" doesn't have the amazing service you get at "Big Wong." But the "Chicken Wrap Wrap" was perfect, because it should have been, but it wasn't really. That was another $2.50 I don't have extra cash I can spend. The chicken wrap was fresh and seasoned for you to choose and it was a big, warm piece of white rice that had a perfect combination of salt and soy. That is because it is really rice, in all the right ways.
#
# The main reason I love "The Bingshu" is the "Big" Curry. Which was in fact the "big" Curry (if you're still reading), and again, everything tasted great. I had a curry bowl that was quite large in size, and was able to split that down to 4-5 people, but I did love the large portion of Curry for the large bowl.
#
# I can't talk about the food here because it was such a big bowl, and I'm sure they were in it for a good part of the time it took to get everything started. (You need to put the extra effort.)
#
# My only complaint (for my Thai "no noodle" diet) is having to ask for a little extra sauce. But it wasn't really a big deal, considering it was already hot and the portions were enough for my family members to share.
#
# The only other minor complaint I have is finding out about how often the restaurant will offer free drinks and fried rice, but that's a new problem to me. Because I've been here far too many times.
#
# *Update: * 2/26/13: I've tried other dishes off of the "Big Curry," and I have a much different experience from the "Big Curry" - I'm actually sorry about it. In the regular Curry bowl, I got just the regular rice and this time a little bit extra for my curry bowl's "chicken" sauce. But I still can't complain - so I'm no big deal with my regular bowl.
#
# So the "Big Curry" was great, but with this little extra, I'll say. The "Chicken Wrap." which was a little too sweet.
#
# So if I could change anything in my review: Please, please, please, PLEASE, please please, let me know if you're in the mood to "Hummus Wrap" and let me know how you're doing.<|endoftext|>
# <|startoftext|>I recently moved to LV from Phoenix and I was in need of moving.  I found this company on Yelp and was happy to find moving services.  The crew was great, friendly and informative.  I was able to pick up my furniture in less than an hour and I was amazed how fast my belongings made it! Thank you for this amazing service.  Thanks once again.<|endoftext|>
# <|startoftext|>A favorite of yours!
#
# It's one of my more expensive restaurants, so make sure to make reservations. The restaurant was busy at our table of 3. We were seated right away. The restaurant had
#
# [5005 | 42245.29] loss=2.76 avg=2.98
# [5010 | 42340.26] loss=3.15 avg=2.98
# [5015 | 42434.65] loss=3.04 avg=2.98
# [5020 | 42529.63] loss=3.07 avg=2.98

# %% [markdown]
# ### Training for GPT2 large (Review 5 Filtered Food)

# %%
import gpt_2_simple as gpt2
import os
import requests

model_name = "774M"
file_name = "review_5_filtered_food.csv"

if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   

# %time
sess = gpt2.start_tf_sess()
gpt2.finetune(sess, \
              file_name, \
              model_name=model_name,\
              run_name = 'review_star_5_large_food', 
              steps=5000,
              print_every = 5)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.25 µs
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint checkpoint/review_star_5_large_food/model-4000
# INFO:tensorflow:Restoring parameters from checkpoint/review_star_5_large_food/model-4000
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:03<00:00,  3.75s/it]
# dataset has 36643718 tokens
# Training...
# Saving checkpoint/review_star_5_large_food/model-4000
# ======== SAMPLE 1 ========
#   I'm also a fan of their cocktails here but I will admit that the most famous cocktail isn't the sweet and fruity one I've never tasted. I prefer the  ginger sour...
#
# I've been to Vegas several times in my life and have eaten here several times.  The service here has always been extremely quick (the bartenders even have a little bar stools that serve the tables).
#
# You can't go wrong with anything on the menu here, the service is fantastic, and the food is always good!  I really enjoy trying any of the different plates and the food is always delicious.
#
# When I think about the word "diciness," I think of that word.<|endoftext|>
# <|startoftext|>Wow! A place worth the drive to the Fremont Street. It was a great night and one of the best dinners I've been to in Vegas. I had the sushi salad consisting of two pieces of fish in a beautiful salad of scallops.
#
# If you haven't been coming back here in the past few months...
#
# GO!
#
# Make sure you call and ask for a reservation and then just tell them so.
#
# This place is perfect on everything.  The menu changes each week, so your plate has to be on point. You can order the sushi salad as I did or just order it all. I'm a big fan of the salmon...I think i like it more than most people can even be.  My friend ended up ordering the pork belly...she said she loved it, and I agree but said she is in it's weird.  I'm a huge fan of the karage.
#
# The sushi salad was really good and we each had to take home a piece of fish and eat it like we had never had fish before. That was a nice night!
#
# It all tasted great.  The karage was very tender and was like melted cheese. The scallops were cooked in a creamy miso broth.  The other two items were so good.  I was surprised by some of the sushi choices.  The pork belly was made with fresh scallops.  The salmon belly (again cooked very well) was a bit overcooked.  You can't really taste what the chef cooked, but everything we ate was amazing.
#
# It's not very expensive.
#
# We had an amazing time.  The drinks for the night were $5.60 (pours and a $2, and you can add all of these to your bill).  There is no charge for a mimosa...you get what you pay for a couple drinks and it wasn't even needed.
#
# The bar is small, but there are 2 or 3 bars.
#
# My only complaint for the service was that sometimes there was a wait to get our check.  Once again...good service, good food, good value for money.
#
# I can't wait to eat here again!<|endoftext|>
# <|startoftext|>A good place for a bar...it's the only place on the strip that I ever want to go back to.
#
# The music is pretty good and there are some good blues selections (thanks to my friend's review). I had the salmon nigiri.  The tuna nigiri and spicy tuna sashimi nigiri were each fresh and made with top quality, seasonings.  Definitely get it!
#
# I was able to drink some of the sake on the house--this place has a great selection of craft beers--and it's not the cheapest.  I would probably eat here when it was around $4 a glass of sake.
#
# I found the staff really nice and fun.  They were on top of it.  The only bar not I could think of is the sushi, which are really good.<|endoftext|>
# <|startoftext|>Love, love (I really love this place). Always a hit every time we're here.
#
# I just discovered this place while looking for a good sushi place in Las Vegas because I'm a huge sushi fan, even though I'm not.  I was trying to book my birthday elsewhere in a hotel, so I booked a flight to Vegas and got to wait on my plane in the hotel room of Air New Zealand for around 20-25 minutes for my reservation to be ready.  It took a bit longer, but it was worth it.
#
# I arrived in the morning, but the manager was very kind and asked me to come over and say hi.  I said how awesome is it for me and my girlfriend to come?  He asked if I needed a list of places to eat in Vegas which I said not, but he had the suggestion.  He suggested that we start out at the Grand Cafe (which we made reservations for
#
# [4005 | 487.67] loss=2.94 avg=2.94
# [4010 | 568.44] loss=3.25 avg=3.09
# [4015 | 658.73] loss=3.03 avg=3.07
# [4020 | 751.56] loss=2.77 avg=2.99
# [4025 | 833.94] loss=2.74 avg=2.94
# [4030 | 915.04] loss=3.07 avg=2.97
# [4035 | 996.71] loss=2.82 avg=2.94
# [4040 | 1078.14] loss=2.79 avg=2.92
# [4045 | 1160.24] loss=3.23 avg=2.96
# [4050 | 1240.83] loss=2.98 avg=2.96
# [4055 | 1321.49] loss=3.25 avg=2.99
# [4060 | 1403.28] loss=2.84 avg=2.98
# [4065 | 1483.77] loss=3.20 avg=2.99
# [4070 | 1564.82] loss=2.87 avg=2.98
# [4075 | 1645.68] loss=3.28 avg=3.01
# [4080 | 1727.80] loss=2.64 avg=2.98
# [4085 | 1808.63] loss=2.96 avg=2.98
# [4090 | 1890.13] loss=2.83 avg=2.97
# [4095 | 1970.97] loss=2.79 avg=2.96
# [4100 | 2052.89] loss=2.87 avg=2.95
# ======== SAMPLE 1 ========
# ura>
# <|startoftext|>Love it here!   The chicken's are soooo bomb dot com!
#
# Love the cleanliness, atmosphere, quality, and price of the location!   The employee that was working the machine was a little nervous I would take away her toys and eat her for a bite.   I am totally into the concept of going to an oggie market to buy a large basket of vegetables for the weekend!
#
# Love the prices!   This is the only place in town that I love.   I cannot stop coming here and can't wait to return!<|endoftext|>
# <|startoftext|>This is my third time at Oggie Market. The first time I was eating at the Oggie Station and this time was for the second time - it was good, but this time it was a little different. They had a large variety of local produce. They even had some fresh greens and even had some imported produce. They also have eggs, and meat for those that are looking for a quick and easy lunch! The staff were friendly and very kind enough to help me decide what to buy for me. I ended up buying several types of fruit and vegetables and ended up saving enough for later in the week!<|endoftext|>
# <|startoftext|>I love Oggy's for the variety of products they carry. From their fresh produce, baked goods, meats, to the seafood section they offer a great selection.   I have been here several times, but I have only tried what is available.  They also offer many different types of pasta, which if you are a fish fan, you can find the varieties the fish has always been known for. This is an OPGECIALLY a lot for the prices you receive here
#
# I have come into many many times and have made the decision to order with my family whenever I go here.  If you come here early in the morning, you can enjoy their breakfast. They serve breakfast as well and they offer a buffet. They also have lunch. I think they close around 2-3 and open 24 hours, though I have to call to confirm as I have been to many O.G. coffee shops.
#
# I always make the trip in the late afternoon or evening on my way to work and have the place set around my dinner.  I'm not going to lie, the food is a bit different the second time I stopped here. Sometimes it is a buffet style as the place serves their selection of food, but I like that style just the way that they do.
#
# When they serve me, they actually have a wide variety of baked goods to chose from. Their oatmeal, sugar cookie, pecan pie and coffee cookies are all good to me. I have no excuse not to eat one. I will go into town and I am going to get another one for the car tomorrow.<|endoftext|>
# <|startoftext|>One night I decided to find someplace to celebrate a friends birthday.  I didn't know where to go so I decided to come here first by chance and second by recommendation... and third by Yelp.
#
# The food is delicious.  What is the deal with the large amounts of fresh fruits and veggies?
#
# The drinks are very reasonably priced.  The servers were very efficient with the cleaning up after the tables came down.  I will definitely come back for the best food and customer service.<|endoftext|>
# <|startoftext|>YUM! This whole place is awesome. There is so much to choose from! You can get produce from here! They're always growing, but the customers are getting full fast!! I love that you can always get fresh baked goods here!!<|endoftext|>
# <|startoftext|>As the husband and wife of this guy from the other reviews we love to get his oatmeal here all the time. The quality of the product is always consistently good and the employees are very nice. The prices are good if you can eat in a lot of free parking.
#
# I always have their waffles and eggs and it is the best I've had.
#
# They always give us free treats for when we go in there.<|endoftext|>
# <|startoftext|>O.WOW. I've searched over 30 minutes before I am leaving here and I can't believe it's located in a mall on top of the mall's tallest building. I had the opportunity to see the new and shiny building of this new and shiny building, and decided to come here. I was pleasantly surprised and excited with the first sight of this new and shiny building. I was pleasantly surprised because this building is small and a bit out of the ordinary buildings in that same shopping center. The building was clean and neat and there was free parking. And I thought
#
# [4105 | 2469.32] loss=3.27 avg=2.97
# [4110 | 2547.75] loss=2.94 avg=2.97
# [4115 | 2626.33] loss=2.80 avg=2.96
# [4120 | 2705.26] loss=3.21 avg=2.97
# [4125 | 2783.66] loss=2.81 avg=2.97
# [4130 | 2862.39] loss=3.60 avg=2.99
# [4135 | 2940.31] loss=2.94 avg=2.99
# [4140 | 3019.58] loss=2.44 avg=2.97
# [4145 | 3097.98] loss=2.90 avg=2.97
# [4150 | 3175.76] loss=3.53 avg=2.99
# [4155 | 3254.08] loss=3.07 avg=2.99
# [4160 | 3333.05] loss=2.33 avg=2.97
# [4165 | 3411.11] loss=2.60 avg=2.95
# [4170 | 3489.40] loss=3.04 avg=2.96
# [4175 | 3567.27] loss=3.20 avg=2.96
# [4180 | 3646.15] loss=2.80 avg=2.96
# [4185 | 3724.66] loss=3.09 avg=2.96
# [4190 | 3802.71] loss=3.02 avg=2.97
# [4195 | 3880.86] loss=3.28 avg=2.97
# [4200 | 3960.06] loss=3.22 avg=2.98
# ======== SAMPLE 1 ========
#  for your lunch buffet here. It is also by far one of the restaurant's best choices.
#
# You just gotta have an empty hand and try this place out- don't just skip it with your deliciousness- the portions are generous as always.<|endoftext|>
# <|startoftext|>Stuffed avocado salad. So good. So tasty. I know how you may say what's in it. You'll be shocked.<|endoftext|>
# <|startoftext|>Love, love, love for this place!!!
#
# I just want one word to describe the ambiance at this place, it's a simple design, it's classy, yet beautiful. The colors really blend together for that kind of modern restaurant feel. It really sets the mood to classic diner food, without getting too fancy. Even in the dim lighting when we sat out here, that place got quite a bit of attention. We had a reservation, so we got in on the show during dining hours. The staff was friendly and prompt with drinks, so everyone is friendly.
#
# The food is good for four people. We ordered the chicken and waffles, French toast and sausage bisque. The food was amazing. The chicken and waffles was crispy and fried to perfection and the mashed potatoes were a huge hit. The sausage bisque was perfect too, I had the meat and potato side, perfectly sauced and not salty, very easy. That's a big win. The bread was amazing as well, I was too full to have dessert but the bread was perfectly crisp and fresh. To compliment the dish you get some good bourbon.
#
# The only downfall is that it can be rather loud when there is a party here, but I had to go in order to get to a movie. There were people in the theater room and it was nice to have a seat, with the noise level at the restaurant, so the music didn't really disturb anyone else or our neighbor, we saw it coming from all the bars out there, music blaring from the street traffic and it was nice to catch something else.
#
# The only flaw, in the end the waitress forgot we were with them and brought along more food!
#
# We had the chicken and waffles (which are pretty much as a side in themselves) and the cornbread. Both were delicious, my favourite were the crispy, juicy pieces of meat to the waffles. Both were seasoned, the side had a nice crispy sweet butter-brown taste without taking over the flavor of the dish. I'm not much of a biscuits person, but we were just there to dine and that's it.
#
# This is as good as it gets. I was able to sample both the breakfast and the dinner portions of their respective dishes, which was also good. Service was great and it's a nice place to relax and catch up with your foodies, no need to rush or sit in a bar/restaurant like I do.
#
# I wouldn't like to call it dim, it's gorgeous in there, dark, quiet and romantic- but it's perfectly cozy and quiet and romantic for what it is the perfect meal setting.<|endoftext|>
# <|startoftext|>A very large and quaint space! If you're planning on hosting a dinner with family, it is recommended that you request this. It is so nice to see it full of people and tables. We had reservations to get back to the lobby, but were able to get seated shortly.
#
# Our hostess was very friendly and attentive. She was very understanding and informative.
#
# We ended up making three reservations for their first half of their night, but only being slightly delayed to our reservation time. But the hostess and her staff were so accommodating when we informed that we wanted to try the whole suite. Our group started off with cocktails and wine, but they didn't let us know how it was going to be. They gave the hostess a basket of different breads and buns that were not included with the dinner reservations. A bit surprised me since there seemed to be butter and buttercream. The breads were crispy and very tasty. I also really liked some pieces of corn on the cob that were in the breading.
#
# For dinner we ordered the oysters, the crab cakes. We were able to eat everything as they are served in a large jar. I ordered the sea bass entree. It was so delicious. The sea bass was perfectly cooked and had great flavor of spice. My boyfriend ordered lobster risotto which were both very tasty. I tried the clam ravioli and enjoyed it as well. He tried the crab cakes and it was also very good.
#
# The ambiance, decor and the people around were perfect for us. The service was great and our food was delicious and it was a really great night.<|endoftext|>
# <|startoftext|
#
# [4205 | 4374.58] loss=2.84 avg=2.98
# [4210 | 4451.09] loss=2.91 avg=2.98
# [4215 | 4528.60] loss=2.68 avg=2.97
# [4220 | 4604.68] loss=3.03 avg=2.97
# [4225 | 4681.85] loss=3.26 avg=2.98
# [4230 | 4757.93] loss=2.92 avg=2.98
# [4235 | 4835.06] loss=3.59 avg=2.99
# [4240 | 4911.46] loss=3.27 avg=3.00
# [4245 | 4988.69] loss=2.76 avg=2.99
# [4250 | 5065.07] loss=3.24 avg=3.00
# [4255 | 5142.00] loss=2.85 avg=3.00
# [4260 | 5218.02] loss=3.01 avg=3.00
# [4265 | 5294.52] loss=2.91 avg=2.99
# [4270 | 5370.48] loss=3.54 avg=3.01
# [4275 | 5447.17] loss=2.68 avg=3.00
# [4280 | 5523.58] loss=2.95 avg=3.00
# [4285 | 5600.29] loss=2.61 avg=2.99
# [4290 | 5676.42] loss=2.67 avg=2.98
# [4295 | 5752.49] loss=3.08 avg=2.98
# [4300 | 5829.34] loss=2.69 avg=2.98
# ======== SAMPLE 1 ========
#  for about $75 per person. They were a lot of food and food and really it was a great value.   It was not too expensive considering the quality and you didn't have to pay for your food with butter or sauce.
#
# Everything we had was delicious, fresh in a good way, and all in all it was a huge hit for my wife and I (a bit hard to mess up now where you can order that and get your food with a bunch of different sauces and toppings and then have it with garlic or not in the pasta) and really a big food item for us.
#
# It's hard to see how people can't get it again as we are sure they will be trying something a little different next time.  Our only negative was that I guess they just keep cutting it so they don't have a huge problem and it never seems a little dry.  Well, if you did get a large plate with some of the other things they do it on the side of the rice that was pretty dry.  I guess you can't get an order done without rice.  They do have a pretty decent pasta dish but I think it is a little small.<|endoftext|>
# <|startoftext|>Came here on a weekday, we both went for take out and everything was great.   The food was a little on the pricier side for a large group of us.  I ordered their Thai Veggie Chicken which was a large portion.  The food was really good and prepared very well.  The person who helped us ordered the Green Curry as well as their Tofu Beef dish.  When it was time to leave we were both very happy with how everything was.  Great food and the service really was that great and attentive! The place is small and a little pricey compared to other Thai restaurants on the street.   The place is small however, very clean  and the menu looks like a real Thai restaurant.  It is definitely not for everyone or anyone who thinks about trying something different with their food. So far, I've tasted my food in their Veggi Soup (veggie-dairy-vegetable-fried-chicken) and in their Green Curry dish.  It was delicious!<|endoftext|>
# <|startoftext|>The last time I was in town I ate at a Thai restaurant but this time my friend had not yet been to this place, so I knew I had to try it.
#
# I had not been before but I ordered the Green Curry, my friend had their Pad Thai dish with a side of fried rice and I ordered the Thai Pork Pad See-Eung with a large serving of shredded meat (I did not try the fried rice).
#
# All I could do was get a taste! I tried both and all the dishes were delicious. The Green Curry was really good too, but a lot to absorb. My friend was not the biggest fan, but I was too big and he said it was delicious and had some of the best he has had in the city.
#
# On a side note I must say the other food didn't seem like too spicy. So I am surprised this is a different restaurant. It could be that the other restaurants overuse a lot of spice on these dishes and then use it, but maybe not!<|endoftext|>
# <|startoftext|>I have to say...I cannot find anything bad to say of J.M. Kitchen & Bar!
#
# I had the Tofu beef panang, which was pretty standard (I think because it was a tofu) but the quality and flavour of the dish was excellent. I don't know if this means more or less than it's usual version, since the meat was fresh and moist and the sauces were a lot of different ones. The tofu was cooked perfectly, and the dish is definitely not what I'd expect.
#
# The green curry was surprisingly tasty too! My friend had a curry dish with chicken and it did not fare as well as his other dish, but the Green Curry was really good and the vegetarian rice that comes in with it was also very good.
#
# For those who like this type of food, this might not be for you, but you will definitely come back, and will leave satisfied and happy as well!
#
# I would absolutely recommend this restaurant as someone to order from if you are in the area, and definitely try it if you are someone with friends, or if someone new is coming!<|endoftext|>
# <|startoftext|>Went the first time last month and the second time was not a disappointment. When I asked the owner what was special for the current month he told me the new lunch special is their takeout restaurant that serves up the best and most authentic Thai food in Vegas - and does it every time possible (I believe that's just
#
# [4305 | 6245.41] loss=2.64 avg=2.97
# [4310 | 6322.98] loss=2.99 avg=2.97
# [4315 | 6401.78] loss=3.13 avg=2.97
# [4320 | 6480.59] loss=3.17 avg=2.98
# [4325 | 6558.28] loss=2.72 avg=2.97
# [4330 | 6636.21] loss=2.62 avg=2.97
# [4335 | 6714.45] loss=3.32 avg=2.97
# [4340 | 6791.69] loss=3.22 avg=2.98
# [4345 | 6869.35] loss=2.84 avg=2.98
# [4350 | 6947.24] loss=2.94 avg=2.97
# [4355 | 7025.82] loss=3.19 avg=2.98
# [4360 | 7103.98] loss=2.55 avg=2.97
# [4365 | 7181.70] loss=2.47 avg=2.96
# [4370 | 7258.96] loss=2.77 avg=2.96
# [4375 | 7337.52] loss=2.84 avg=2.96
# [4380 | 7416.94] loss=2.91 avg=2.95
# [4385 | 7494.53] loss=2.72 avg=2.95
# [4390 | 7572.46] loss=2.65 avg=2.94
# [4395 | 7651.49] loss=3.05 avg=2.95
# [4400 | 7729.82] loss=2.97 avg=2.95
# ======== SAMPLE 1 ========
#  we had a very low volume of the room which was just enough for us, my hubby and I, to have the best view of the entire place.
# This time, I could see the whole thing...
# It was very good, nice view, not to worry about the light going out on you, a nice view, nice music and the right amount of dark wood.
# This time, we chose a small room with an amazing view of everything, the view, the views, the pool. This time, we opted to spend about $50/night for dinner.
# This time, we opted for the $70 each for our 4-course meal.
# The food and service were also both great.
# Our server was great and attentive to our every need. He was on top of our dinner and was attentive to our needs. I could have waited on him to be our server.
# The food was great. We tried the tuna steak, the clam, the lobster, the crab meat, the salmon, the pork belly and seafood. All very good.
# We tried a little of the shrimp which were all very good too.
# The last thing we tried was the shrimp cocktail. It was good but the shrimp was small and I would not call this a shrimp cocktail.
# We have been to many local restaurants and most of them cost me more than you will spend at the strip.
# That's what I liked about Bellagio in Bellagio.<|endoftext|>
# <|startoftext|>For years, there have been no shortage of "must-see" buffets in Vegas. What makes this place stand out from the crowd is that it is a buffet, where all the culinary/foodie goodies and local restaurants come in.
#
# My family and I always have a great time here. It's really the only place I haven't stayed at, and still don't regret that decision.<|endoftext|>
# <|startoftext|>My cousin introduced me to this buffet (since they finally have the same restaurant!). It's pretty much the BEST buffet on the strip, hands down. I never heard of the name, or the food anyway. I always figured it out (luckily I had the most important thing to go, the seafood dinner), but it took me over a few seconds to figure out what to order on my seafood. But there was no wait! I ordered shrimp prawns. Wow wow, wow. The shrimp was a big chunk of thick shrimp meat, cooked just right for me. This also didn't have shrimp in it. It was a huge shrimp and crab mixture, like a mongolian version of shawarma. It was very good, but I'm not sure if it's the real deal, but I was thinking it was delicious. Next I ordered the al pastor. This is my absolute favourite thing there! It is a bit on the heavy/sweet side, and the fried rice was ok, but I like rice a bit more.  And I love fried rice! There are a bunch of different sauces at this place, but I personally didn't taste one I didn't want to put in it! I was really excited to say that there is actually fried rice here, so I ordered it fried anyway. It was fried in a delicious garlic garlic sauce. This one was the best, I actually don't know how they put it in it! My friend ordered salmon. It was perfectly cooked so that the salmon was not soggy at all. I'm not sure what their special sauce was, but I was super excited at the end of eating that. It had salmon in it, which came in a big piece, super light, and it tasted like an omelette, but without the usual garlic sauce. This one was amazing, but there were a few other things that I would have liked to have in it. For me, all those are definitely overrated items, and the poutine is the one I wish that they wouldn't make because I love tuna tuna so much, but if I make an order of albacore tuna I don't think the waiter would know what kind to let you order with. I had a shrimp, but for some reason my friend got a shrimp for her dish. But overall, if I am ever in Vegas, this isn't on the list of must-sesses I want to go. But I love seafood and I can taste it, so what can I say? That is my absolute favourite buffets.<|endoftext|>
# <|startoftext|>I really enjoyed my dining experience at the Bellagio. From start to finish, I was thoroughly impressed in my first impression and my first impression was still even better when I left. This review is of a night when I had the lobster bisque which was cooked perfectly medium rare-medium, was beautifully presented, and just as a nice lobster roll.
#
# [4405 | 8154.85] loss=2.92 avg=2.95
# [4410 | 8232.48] loss=3.68 avg=2.96
# [4415 | 8312.43] loss=3.24 avg=2.96
# [4420 | 8390.25] loss=3.16 avg=2.97
# [4425 | 8467.86] loss=3.01 avg=2.97
# [4430 | 8545.49] loss=2.88 avg=2.97
# [4435 | 8625.17] loss=3.74 avg=2.98
# [4440 | 8702.58] loss=2.84 avg=2.98
# [4445 | 8779.89] loss=2.61 avg=2.97
# [4450 | 8857.76] loss=2.81 avg=2.97
# [4455 | 8936.59] loss=3.15 avg=2.97
# [4460 | 9014.21] loss=2.78 avg=2.97
# [4465 | 9091.81] loss=2.68 avg=2.96
# [4470 | 9169.71] loss=2.71 avg=2.96
# [4475 | 9249.86] loss=2.94 avg=2.96
# [4480 | 9327.28] loss=2.90 avg=2.96
# [4485 | 9404.75] loss=2.87 avg=2.96
# [4490 | 9482.74] loss=2.97 avg=2.96
# [4495 | 9561.98] loss=2.83 avg=2.96
# [4500 | 9639.63] loss=3.00 avg=2.96
# ======== SAMPLE 1 ========
#  Well were told they can make the same dishes as the previous place.  Was told the menu has moved too and changed.  We were disappointed to see it, but we were told if you're a fan of the food you should stick with it.
#
# Anyway, we were told they would offer delivery through their website, and I will definitely be back there soon.  This place is very convenient for customers to eat at anytime of the day, and I do not have one problem with it!<|endoftext|>
# <|startoftext|>I love this place to have a good dinner place. I usually get the same thing. I typically order from a traditional, "courier"; the menu items I have been given always sound familiar. I know the dishes that have been used to make so many souffles. But not only do I understand the intricacies of a souffle, I am a fan of the presentation. I am a fan of the flavors of the souffles. I know that I eat souffles a few times a week. In fact, I have to make sure I keep this place open so I make sure I make it every day. I love the souffle dishes! I know each souffle is homemade, the service is incredibly attentive and the food is perfect. I have been going there since I was a big fan of the souffle on the menu, probably a couple of years. The souffle is so delicious. The cream of mushroom and cheese, and of course, the cheese and mushroom. You cannot go wrong, and the bread is always just a little dry to me. If you are not a big dough eater, I recommend a side salad of their fresh homemade coleslaw. It has cheese and some great pimentation. It is not overly greasy too. The portion sizes are huge. And I think I have made enough dough to feed my family...no?<|endoftext|>
# <|startoftext|>Came here for a dinner date with my husband. A few of the reviews do not know how to rate that place. I am not sure exactly why. This is a really excellent place if you want to dine out with friends and/or you are a special occasion or just for me as the wife. The servers are great and fun. I have also met some friends and their names are on the menu.
#
# I tried several souffles. The lemon pepper, cheese paste, brie, apple, and goat cheese souffle is great and I have to say that I was in a bit of a mood that day. I really don't appreciate how they display it on your menu though and it looks a little strange to put all that sugar into the soup. I do know they use real cream of mushroom, not corn syrup. It makes sense but that's how it is made and I was concerned that I would have gotten a side of mush (boulew) on the first order I had and the taste I wanted that day. The cheese paste is delicious too! The pita bread is excellent as the bread is so fresh and so delicious. I had an appetizer which I thought was so good I almost ate it all the time, especially when it has cheese. My husband ordered from a typical French place and that was just what we ordered but he left an order, so he had to leave it. I ordered a lamb souffle from a French place and it was amazing. The dressing is wonderful as well and it had a kick that wasn't overpowering. We both get these souffles at once so you're not stuffed. I can say that you can have an enormous meal here even on a weekday.
#
# All all I have to say is, you will not be disappointed.<|endoftext|>
# <|startoftext|>My husband and I had dinner at Souffle Noix in Paris for our anniversary. The food and service were AMAZING! We loved our service from beginning (with just a good Champagne and a warm welcome from the staff) through our meal, and were very well taken care of. I tried the Lemon Pepper souffle that had lots of butter and lemon on it, which was a very enjoyable and refreshing way to start a dinner. The steak tartare was very, very good and the soup was so delicious and just the right texture. Our waiter was very knowledgeable about the menu and made great suggestions. I'm looking forward to going back for dinner to try other souffles that are featured on the menu, and I am glad I will be back! And again, thank you Souffle Noix and your staff!<|endoftext|>
# <|startoftext|>Love this place! I like it with a little spice and tons of freshness, and sometimes it does get a little bit too fancy for its own reasons,
#
# [4505 | 10055.48] loss=3.08 avg=2.96
# [4510 | 10136.34] loss=3.20 avg=2.96
# [4515 | 10214.24] loss=2.88 avg=2.96
# [4520 | 10292.51] loss=3.01 avg=2.96
# [4525 | 10370.17] loss=2.98 avg=2.96
# [4530 | 10449.65] loss=3.05 avg=2.96
# [4535 | 10526.94] loss=2.96 avg=2.96
# [4540 | 10605.09] loss=3.30 avg=2.97
# [4545 | 10683.47] loss=2.97 avg=2.97
# [4550 | 10762.02] loss=2.65 avg=2.96
# [4555 | 10840.21] loss=3.37 avg=2.97
# [4560 | 10918.43] loss=2.69 avg=2.97
# [4565 | 10995.69] loss=3.26 avg=2.97
# [4570 | 11076.90] loss=2.92 avg=2.97
# [4575 | 11154.94] loss=3.22 avg=2.97
# [4580 | 11232.43] loss=3.00 avg=2.97
# [4585 | 11309.98] loss=3.54 avg=2.98
# [4590 | 11389.77] loss=3.15 avg=2.98
# [4595 | 11467.66] loss=2.74 avg=2.98
# [4600 | 11545.41] loss=2.72 avg=2.98
# ======== SAMPLE 1 ========
#  more fresh produce.  If one needs a "healthy" menu - I'd suggest having the Avocado Avocado sandwich.  The bread is pretty good but needs a bit more dressing.  You can also order the "Pancini Fries" which are slices of grilled beef brisket and a side of Fries.
#
# Service is good.  I like that the kitchen isn't working at full tilt so you can see all of the menu items.
#
# The only thing I'd suggest is to ask for a "small" price cut (ie 1/2, 1/3, etc).  They offer a "medium" price for $6.99 each.  It's not too bad at a great price!
#
# As for the food - don't forget to try their famous Salads, which taste so good!  I highly recommend the Prosciutto & Avocado salad and the Tenderloin of Lamb, both with jalapeño fries.  And, if it's not enough - you get a side of their famous Cucumber Fries.
#
# The staff is very friendly - service is fast and friendly. They offer a variety of salads to choose from and take out.  There's an outdoor patio and if you want a quiet dinner after 8pm - well, they're in a perfect place.  Don't worry - they have a large space for the patio where you can enjoy watching the world go by.
#
# My girlfriend and I just returned from lunch and we both had a "great" experience here.
#
# Don't forget your wine list.
#
# This is a fine dining restaurant located in a very chic part of downtown.  You can tell a lot about the kitchen, which I love :)
#
# This is a clean, upscale restaurant that is very well-maintained and looks elegant.  It's clean and a lot more modern than a typical Mexican restaurant.  So I'd definitely say it is clean!<|endoftext|>
# <|startoftext|>We got lucky and they were able to make this our first night of 2016! This place was amazing! We absolutely loved it! Food was fresh, the staff was very helpful and informative, the location just is beautiful, and all of our drinks were on point! I absolutely loved it! They were a lot on the pricier side, but you get what you pay for. I would definitely recommend this place for a date night or just for a fun night!<|endoftext|>
# <|startoftext|>Amazing food. Our server was on point and the food came in and my boyfriend had to take me back back and I cannot even put into words how good it was. The portions were huge and everything tasted amazing. The avocado cheese bread is a must try.  I will certainly be back to try a different dish.<|endoftext|>
# <|startoftext|>Love the ambiance of this cozy little bistro. My husband and wife shared a special tasting platter so we could share it and also get a chance to sample many different drinks. We loved not only the taste of the food, but I also loved enjoying the cocktails as well. This is definitely a must try for anyone wanting a nice tasty dinner in Madison.<|endoftext|>
# <|startoftext|>Amazing restaurant with top-notch food, good cocktails, great wines, good drinks, great wine list and friendly bartenders. It's a wonderful hidden gem. I'm glad that this is closer to home! Great drinks and good food, too.<|endoftext|>
# <|startoftext|>Holy cow. What an incredible experience...we all enjoyed both of the meals.  Everything was fresh, every flavor was true, and we all had a fantastic meal.  I highly recommend this place to anyone looking for great quality, flavorful food and great company.  This is definitely the kind of place I will return to for a drink, lunch, or dinner.<|endoftext|>
# <|startoftext|>Holy cow! This place is awesome. If you're from California, you have to try this place, well... I ordered a sampler plate and it was delicious! I also tried the pork belly and the chicken sashimi and it was so good. I highly recommend this place. Just go try the chicken sashimi, not too spicy and the pork belly is good with your rice. My boyfriend ate the sushi with my rice and said it was tasty. I would say be careful of the sauce that comes with it because it's all just so good! And you gotta try some sashimi too! If you're from California, you have to go check this place out!<|endoftext|>
# <|startoftext|>This place has a few new things going on.
#
# This place is now open
#
# [4605 | 11961.45] loss=3.09 avg=2.98
# [4610 | 12040.91] loss=3.16 avg=2.98
# [4615 | 12119.08] loss=2.53 avg=2.97
# [4620 | 12197.61] loss=2.57 avg=2.97
# [4625 | 12276.26] loss=2.77 avg=2.97
# [4630 | 12355.14] loss=2.62 avg=2.96
# [4635 | 12432.96] loss=3.23 avg=2.96
# [4640 | 12511.12] loss=2.79 avg=2.96
# [4645 | 12589.38] loss=2.87 avg=2.96
# [4650 | 12668.66] loss=3.23 avg=2.96
# [4655 | 12746.96] loss=2.96 avg=2.96
# [4660 | 12825.71] loss=3.00 avg=2.97
# [4665 | 12904.15] loss=2.96 avg=2.97
# [4670 | 12983.48] loss=3.07 avg=2.97
# [4675 | 13061.67] loss=3.60 avg=2.98
# [4680 | 13139.73] loss=2.98 avg=2.98
# [4685 | 13217.53] loss=3.69 avg=2.98
# [4690 | 13296.75] loss=2.73 avg=2.98
# [4695 | 13374.71] loss=3.11 avg=2.98
# [4700 | 13453.00] loss=2.43 avg=2.98
# ======== SAMPLE 1 ========
#  serving on that day. We got here around 10pm and sat right away. (We got there around 10:30 on a Saturday night.)
#
# My friend and I were greeted by the bartender, whom was very friendly and friendly. The bartender then told me the menu and the drink orders and took our cue.
#
# The ambiance and ambiance was nice. Nice lighting, nice ambiance and the staff was very knowledgeable in their menu and knew what they were doing. The food was absolutely amazing. We started with drinks and the drinks were super cheap for that time. My friend got the "caviar and green wine". I had some kind of green wine but he said it was some nice version of a viet gin (so good!) and I couldn't tell by the flavor in there (the best part it looked good).
#
# For dinner I had my friend order something which was pretty good considering he was at that time too full for a great meal so I got the entree and it was big enough. I got a large portion and shared it with a friend. The bread was soft so they could slice it with a spoon. I didn't order another dessert as some other people came shortly after to order but I will definitely be ordering it next time.
#
# The appetizers were the specialties. I had the char siu and my friend got the char siu dumpling of some sort, they were both awesome! The char siu and the quail egg were my 2 favorite things. It came with a sauce of some sort/ sauce (i forgot the name of it) but it came with white rice. The quail egg was a mix and came with two mini pieces of quail egg fried in a sweet sauce. This was a really nice change of pace from all the food we had that afternoon. We also tried a new drink that came with two vodka glasses of wine. We loved the gin martini which came with a gin martini, the vodka was amazing.
#
# We also ordered dessert. I had the baklava which came in a big bowl on a plate. It was pretty tasty but I wish I ordered the whole bowl as the portions were a little too big for me to finish.
#
# If you get a craving for some authentic Chinese food you have to try The Wok Chinese restaurant in downtown Calgary. It does close at 6pm but I know there are people who still work here so I will be coming here as I do for sure next time.
#
# Overall I will say that a lot of their restaurant was of Chinese/Chinese dishes (like the wok chao chicken and chow fun). I like the fact that this restaurant had all the dishes in the menu for all patrons. It also had all the sauces, except the sauce.
#
# Thank you for the awesome food and excellent service!<|endoftext|>
# <|startoftext|>Excellent food was excellent service was excellent.
#
# I have been looking forward to trying this place every time I visit Toronto! The food here is great and everyone was happy.
#
# I would recommend the chicken bao, it was very moist and the spicy sauce was tasty, it came with onions, cabbage, carrots, and fried egg.
#
# My friend ordered the chicken chow mow which came with fried rice, spicy pork chops, hot chicken, broccoli, spicy broccoli, and a spicy sauce.
#
# The chicken kung moh was super special! Super crispy fried chicken skin and the chicken was not dry like most other chicken casseroles.
#
# The crispy fried egg was super crispy on the outside and the egg was amazing.
#
# The fried rice was very good as did the chicken.
#
# The fried vegetables were well seasoned and not too bad.
#
# The hot chicken was cooked very well and was one of my favourite chicken dishes.
#
# I also ordered the baklava and I enjoyed myself a lot.
#
# My friend ordered the chicken sesame balls - it was not bad either, nothing to remember!
#
# I really enjoyed our meal and service of excellent. They have a wide variety of sauces and they seem well trained on how to cook the chicken.
#
# My friend and I ordered the chicken and wok chinese beef and chicken chow mow. The wok chinese beef was ok.
#
# The chicken chow mow came with fried rice, chicken, potatoes, bacon, and a spicy sauce.
#
# The chicken was ok.
#
# The chow mow was ok maybe it was the sauce that made it good, it was also the chicken and the potatoes.
#
# I would definitely be coming back here in the near future.
#
# I also forgot to mention that it was not too big at 7$ per person for all this.
#
#
# The service was excellent.
#
# The staff that was serving
#
# [4705 | 13869.69] loss=3.14 avg=2.98
# [4710 | 13946.92] loss=2.77 avg=2.98
# [4715 | 14025.56] loss=2.36 avg=2.97
# [4720 | 14104.36] loss=2.76 avg=2.96
# [4725 | 14183.19] loss=2.77 avg=2.96
# [4730 | 14262.29] loss=2.79 avg=2.96
# [4735 | 14340.55] loss=3.74 avg=2.97
# [4740 | 14418.31] loss=3.15 avg=2.97
# [4745 | 14497.23] loss=2.82 avg=2.97
# [4750 | 14575.69] loss=3.06 avg=2.97
# [4755 | 14654.37] loss=3.07 avg=2.97
# [4760 | 14733.75] loss=3.20 avg=2.98
# [4765 | 14813.29] loss=2.61 avg=2.97
# [4770 | 14891.85] loss=2.62 avg=2.97
# [4775 | 14970.09] loss=3.39 avg=2.97
# [4780 | 15055.59] loss=2.84 avg=2.97
# [4785 | 15142.24] loss=2.84 avg=2.97
# [4790 | 15221.11] loss=2.91 avg=2.97
# [4795 | 15299.16] loss=3.36 avg=2.97
# [4800 | 15378.42] loss=3.19 avg=2.98
# ======== SAMPLE 1 ========
#  Fat house salad with tomatoes, artichokes, bacon, and cheese.  The best part... is the price!  The quality and quantity of the food at this location are absolutely exceptional.  I recommend you give this place a try if you are considering the sushi bars.
#
# Sushi Gourmet.  Check it out!<|endoftext|>
# <|startoftext|>I've heard about Sushi Gourmet, but I never made it there.  I was on a Sunday at 1:20 AM and there was a long line, but it filled up quickly.  After a couple minutes wait, another couple came in to pay a buck.  They told me that all time, low prices, regular people and high people are all there.  I wondered: Are all those regular people?
#
# A few minutes later, another couple came in.  They also told me that all time, low prices and regular people are all in this area, so I decided to go.  I had never seen anything like Sushi Gourmet before: not the cheapest sushi restaurant in the area, but not the most expensive either.
#
# We started off with the scalding hot-dogs and they were super good, but the meat was too heavy or not fresh enough.  Not the type of place I'm into sushi, but I did eat them anyway.  Then I tried the oxtail tempura.  I'd been dreaming of oxtail until then but now this was the only poke I'd want on a poke poke.  It was good, but the poke was not as good as it is supposed to be.
#
# The main poke was okay, but nothing special.  I think the only poke that I'd get for sure would be the poke that comes from a poke shell.  I'm not sure if that has been the old poke that came in with poke bowls at Poke Bowl, but it looked the same.
#
# As others have mentioned, I'd definitely see poke bowls as a poke bowl with poke-type poke.  For poke poke, poke bowls don't matter.  Poke Bowl won every poke bowl race in the land.  As far as poke bowls, Poke Bowl wins every poke bowl race.<|endoftext|>
# <|startoftext|>I've been waiting with the anticipation of finally getting to try Poke Bowl. My girlfriend and I were excited by the opening and the poke was delicious. The poke was fresh and flavorful. It's perfect with the Poke Bowl and it does it on poke bowl. The poke bowl is super soft, and the poke poke was so full when we finished it. The poke bowl is a great size and I highly suggest using some soy to fill the poke bowl. I was so happy when we got our poke bowls. It is super crunchy and light after all poke bowls, but it's refreshing how the poke was cooked. This was my first poke bowl and one poke bowl when I have a poke bowl from Poke Bowl again.      I will be back again soon.   If you can't find poke bowls in Las Vegas, this is it here!<|endoftext|>
# <|startoftext|>This is my go to poke poke place if you're interested in poke. Poke bowls are always delicious and this poke bowl is nothing like poke bowls. My first poke bowl experience was when I found Poke Bowl, but I got lost thinking how much poke poke they put. What is Poke Bowl Poke?! Poke Bowls are similar to poke bowls except poke is poke, unlike poke bowls poke bowls poke Poke Bowl makes poke. Poke bowls poke poke poke bowl with poke-poke with toppings and chips and all poke are the same and only difference being poke bowl. They have poke bowl for the whole board so you can try poke poke poke poke poke poke poke poke poke and poke poke poke poke poke poke poke poke poke poke poke poke, poke poke poke poke poke poke, poke poke poke, poke poke poke poke, poke poke poke poke poke Poke Taco, poke poke poke poke Poke, poke poke poke poke poke poke poke, poke poke poke poke poke poke poke, poke poke poke poke poke poke poke poke, poke poke poke poke poke poke, poke poke poke poke poke poke, poke poke poke poke poke, poke poke poke poke poke poke, poke poke poke poke, poke poke poke poke bowls, poke poke poke poke poke poke poke poke poke bowls, poke poke poke poke poke poke poke poke Poke bowl and poke poke poke poke poke poke poke bowls poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke poke
#
# [4805 | 15794.46] loss=2.87 avg=2.97
# [4810 | 15873.67] loss=3.13 avg=2.98
# [4815 | 15952.15] loss=3.00 avg=2.98
# [4820 | 16030.84] loss=2.76 avg=2.97
# [4825 | 16109.41] loss=3.10 avg=2.98
# [4830 | 16187.63] loss=2.82 avg=2.97
# [4835 | 16266.06] loss=2.94 avg=2.97
# [4840 | 16344.91] loss=2.80 avg=2.97
# [4845 | 16423.41] loss=3.07 avg=2.97
# [4850 | 16500.29] loss=3.30 avg=2.98
# [4855 | 16578.59] loss=2.78 avg=2.97
# [4860 | 16657.75] loss=3.38 avg=2.98
# [4865 | 16735.76] loss=2.88 avg=2.98
# [4870 | 16814.43] loss=3.10 avg=2.98
# [4875 | 16893.12] loss=2.52 avg=2.97
# [4880 | 16971.87] loss=3.22 avg=2.98
# [4885 | 17050.26] loss=2.98 avg=2.98
# [4890 | 17128.36] loss=3.19 avg=2.98
# [4895 | 17206.55] loss=2.94 avg=2.98
# [4900 | 17286.17] loss=2.61 avg=2.97
# ======== SAMPLE 1 ========
#  them!
#
# I haven't had one restaurant ever quite similar to "Diners, Drive Ins, & Dives" but the service is always good.  It's a family restaurant so you won't have a huge wait (at least I haven't) and they keep the place hopping, which is great because it's not busy all the time and there are people working.  They have lots of happy hour specials - 5-6pm.  It's definitely a great place for drinks.
#
# I've probably never been here because I thought I'd be too full from the drinks and don't really like going outside until it's too dark.  Anyway, I can say it was very pleasant to go here.  The decor is cool with the large dining room with a table with a bar inside. I really like the large wooden bar and the outdoor patio is nice.  The food is really good - definitely worth coming for the live games and music.  My friends and I both got the fried beef pot pie special which was definitely very delicious.  Our waiter was very friendly and we all really enjoyed our visit and will be coming here more than once.
#
# If you love live music and dancing to the music, and are in the mood to just be around the people, you gotta come here!<|endoftext|>
# <|startoftext|>I'll start my review from the other reviews.
#
# I am a huge fan of the "Diner" concept! I've tried the many other places on YELP and I haven't been disappointed by all of them.
#
# The owners here are some of the nicest people I met here.
#
# For starters, my sister and I came over in the morning around 11ish and were able to snag one of the last tables outside.
#
# Upon entering, we met with 2 extremely friendly friendly and excited greetings from both owner and server. I wanted to have one of the best breakfast in Cleveland or something so I got the "Candy Covered Omelet" with the bacon "Omelet" and my sister got the "Lobster Omelet with the Carrots" with the chocolate "Candy Omelet" and her favorite egg, cheese and fruit."
#
# The service was excellent too, we were treated like family and this is by far my favorite place in Cleveland to eat.
#
# This is my new Fiance to the area and you just gotta check it
#
# My sister said this place is just like what she told me about "The Diner"(Diner) which it was) and I believe she's in love.
#
# The whole experience was phenomenal. My sister didn't want me to leave until we had ordered so we ordered the omelet and the omelet and the cup of coffee to-go and it was perfect. I had the fried chicken, eggs, and grits and my sister had the scrambled eggs, eggs, scrambled eggs and grits.
# So here we are, 11:45am with 4 hours of good quality breakfast, our meal was great, but I would definitely recommend the Omelet.
#
# I will give 5 stars to this Diner, and I hope more people try this place out.
#
# PS. This Diner has a sign on the side stating that they offer a 1/2 breakfast with 1 drink or 1/2 dinner with 5 drink specials and breakfast specials.<|endoftext|>
# <|startoftext|>(What a great breakfast experience!)
# My brother and I decided to try this place and it was great!  It has a great atmosphere (love the patio outside and the outside seating is awesome) and the food was fantastic.  We had the Omelet with spinach and bacon omelet and my brother had the scrambled eggs with grits and a side of grits.  We will definitely go back!!!<|endoftext|>
# <|startoftext|>I love this place. It's a family-run business and the food is fresh and delicious. They have the best coffee ever! They even have real Mexican food which is always really delicious: rice and beans. The owner will have this place on the list of places I need to go the next time I'm in the area!<|endoftext|>
# <|startoftext|>Absolutely wonderful, wonderful little oasis of comfort food and flavor! The chicken is flavorful, it is a family owned business, and most of all, they are truly a wonderful family. I am a vegan and this really has me hooked on it. I cannot comment on the other food other than their hummus (not bad at all) and baba ganoush. The place is so cozy and perfect because of those tiny little oaks of energy. I wish I found this place last week for a meeting at home and we can have a meal here just to make it a daily habit
#
# [4905 | 17701.03] loss=2.70 avg=2.97
# [4910 | 17779.30] loss=2.79 avg=2.97
# [4915 | 17857.59] loss=2.50 avg=2.96
# [4920 | 17937.10] loss=2.75 avg=2.96
# [4925 | 18015.05] loss=3.02 avg=2.96
# [4930 | 18093.18] loss=3.04 avg=2.96
# [4935 | 18170.79] loss=3.19 avg=2.96
# [4940 | 18250.13] loss=2.55 avg=2.96
# [4945 | 18327.52] loss=2.69 avg=2.96
# [4950 | 18405.26] loss=2.69 avg=2.95
# [4955 | 18483.62] loss=2.90 avg=2.95
# [4960 | 18562.95] loss=3.43 avg=2.96
# [4965 | 18641.26] loss=2.92 avg=2.96
# [4970 | 18719.91] loss=2.81 avg=2.96
# [4975 | 18798.11] loss=2.89 avg=2.96
# [4980 | 18877.68] loss=2.92 avg=2.96
# [4985 | 18955.24] loss=2.85 avg=2.95
# [4990 | 19033.77] loss=2.98 avg=2.95
# [4995 | 19111.82] loss=2.79 avg=2.95
# [5000 | 19190.98] loss=2.96 avg=2.95
# Saving checkpoint/review_star_5_large_food/model-5000
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-71e8435a43e4> in <module>()
#      16               print_every = 5)   # steps is max number of training steps
#      17
# ---> 18 gpt2.generate(sess)
#      19
#      20
#
# /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py in generate(sess, run_name, checkpoint_dir, model_name, model_dir, sample_dir, return_as_list, truncate, destination_path, sample_delim, prefix, seed, nsamples, batch_size, length, temperature, top_k, top_p, include_prefix)
#     439         checkpoint_path = os.path.join(checkpoint_dir, run_name)
#     440
# --> 441     enc = encoder.get_encoder(checkpoint_path)
#     442     hparams = model.default_hparams()
#     443     with open(os.path.join(checkpoint_path, 'hparams.json')) as f:
#
# /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/encoder.py in get_encoder(checkpoint_path)
#     107
#     108 def get_encoder(checkpoint_path):
# --> 109     with open(os.path.join(checkpoint_path, 'encoder.json'), 'r') as f:
#     110         encoder = json.load(f)
#     111     with open(os.path.join(checkpoint_path, 'vocab.bpe'), 'r', encoding="utf-8") as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoint/run1/encoder.json'

# %% [markdown]
# ### Training for GPT2 large (Review 1 Filtered)

# %%
import gpt_2_simple as gpt2
import os
import requests

model_name = "774M"
file_name = "review_1_filtered_food.csv"

if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   

# %time
sess = gpt2.start_tf_sess()
gpt2.finetune(sess, \
              file_name, \
              model_name=model_name,\
              run_name = 'review_star_1_large_food', 
              steps=5000,
              print_every = 5)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# CPU times: user 3 µs, sys: 2 µs, total: 5 µs
# Wall time: 9.3 µs
# Loading checkpoint checkpoint/review_star_1_large_food/model-3000
# INFO:tensorflow:Restoring parameters from checkpoint/review_star_1_large_food/model-3000
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:02<00:00,  2.96s/it]
# dataset has 27297071 tokens
# Training...
# Saving checkpoint/review_star_1_large_food/model-4000
# ======== SAMPLE 1 ========
#  the dinner.  Never had a problem before at a restaurant before this.  All the reason was this gentleman who served us was working at the kitchen.  He was working there at about 3:00 pm and we had just finished our first half of our lunch and the guy wasn't even working there yet.  This guy literally came in and walked into our booth and started eating.  He was extremely rude to us.  The guy was so rude and took too long to open the door but when we were leaving we pointed out that he just had the wrong door.
# And I want to clarify that we are talking about the door not being open - yes, he was just being really really rude and he would not let us get up close and walk over to the other end door to wait for that guy to come back so he could actually get to work.  So when he finally opened the door to let us walk over...  he came around the corner with his hand in our booth and did "chase" a little, so now we had to stand up.  We were so ready to leave as soon as we see how this guy treated us.  I just want to say that we are from the Midwest and were looking for a good, friendly dining experience.  This guy clearly could not care less about us.
# But my recommendation:
# 1. The beer is the best part of any and all of our experience this evening.
#
# 2. I will go away from the food and review the bar staff to make a case.
#
# I just would never go back to the restaurant.
#
# I hope this is just a fluke.  This manager needs to be fired and replaced.  It was terrible.
#
# I'll be taking my business other places in Gilbert, and maybe in the Phoenix area.<|endoftext|>
# <|startoftext|>Food was good, had a fun experience, but the staff was not friendly and very rude towards my group and even the entire guest list. The only reason I give them 1 star was that their server apologized to my wife who asked for the manager. Also I'm glad, at least she is not the manager.
# I didn't want to complain to their manager, let's just leave and go somewhere else.<|endoftext|>
# <|startoftext|>I've heard much about this place, but somehow I never thought to stop by.  My husband and I stopped in for lunch, he ordered two tacos and a veal bowl, the restaurant was fairly empty.  He got a salad, which was decent.  The waiter served the tacos, which I thought was interesting.  I thought the food was not interesting, and I have never been out at a hot-pot where the manager is absent. I felt that I was a burden to the manager.
#        The server was polite, at least I was polite.  I can't remember the manager who came by with my order to tell me that my order came with onions.  He came to eat my plate, and he took off before we asked for the manager of this place to apologize for the trouble.
#      My husband then ordered burritos.  I saw a guy eating there, and asked my husband what they had.  He started by complaining about being under cooked (you can see in my photo, he was clearly still too hungry.  We were in the middle of our meal so if I don't see this gentleman, the reason we did not put a $1 tip on the check is to have it, when he put it there on the other servers plate.  I had a $20 bill, I never tipped him on the rest of the bill even though he should not've tipped. I paid the bill.
#     We did not tip and were really upset because if you tip 10 on the tab, they will pay it.  The waiter who brought me the bill apologized, and we were both happy with his gesture and his attitude.  I also noticed him on the food and was nice.  At least, he did not take the full plate into my eye after they took the plate.  I'm surprised we would tip 10 on the bill without the full plate.  It wasn't very nice of him.  We left a $20 tip and left to sit down at a good location.
#          The service was so poor and inattentive.  I don't think their food was bad.  Maybe we weren't hungry, but even our drinks was gross.  They didn't have any of my favorite teas and they had a cup of coffee.  They should be embarrassed that they are getting anything in my money.
#    They had to ask for us to pay our check because the place was really not busy, maybe they just have a good attitude,
#
# [4005 | 465.29] loss=3.02 avg=3.02
# [4010 | 537.57] loss=3.01 avg=3.02
# [4015 | 610.65] loss=2.92 avg=2.98
# [4020 | 684.94] loss=2.84 avg=2.95
# [4025 | 761.98] loss=2.87 avg=2.93
# [4030 | 836.72] loss=3.41 avg=3.01
# [4035 | 912.07] loss=3.37 avg=3.07
# [4040 | 987.08] loss=3.11 avg=3.07
# [4045 | 1064.78] loss=3.11 avg=3.08
# [4050 | 1142.29] loss=2.78 avg=3.05
# [4055 | 1217.75] loss=2.78 avg=3.02
# [4060 | 1291.04] loss=2.89 avg=3.01
# [4065 | 1365.03] loss=3.04 avg=3.01
# [4070 | 1437.05] loss=2.79 avg=2.99
# [4075 | 1509.49] loss=3.41 avg=3.02
# [4080 | 1582.74] loss=2.79 avg=3.01
# [4085 | 1657.29] loss=2.88 avg=3.00
# [4090 | 1730.59] loss=3.21 avg=3.01
# [4095 | 1803.45] loss=2.65 avg=2.99
# [4100 | 1875.47] loss=2.80 avg=2.98
# ======== SAMPLE 1 ========
#  to
# My husband ordered the shrimp and cheese with sauce.
# The crust was just as thin as a half of a quarter of any thin crust. I took a 1/2 scoop and I couldn't finish it. As for the rice. There's more mush inside than inside the shell. The portion is also way too generous for what is basically two small shrimps.
#
# My shrimp was dry and tasteless.
#
# My hubby did the same thing.  The shrimp was the best thing on the menu.
#
# Overall: Avoid at all costs and save yourself $2 for the shrimp. Don't think we'll be back.<|endoftext|>
# <|startoftext|>My wife and I tried out this place out for the first time this past Saturday. She is not a total "I don't know what to think" type person and I wasn't expecting too much. It was a decent food court type of place with a couple tables having a great time at the bar getting the drinks and food and more food.
#
# The hostess looked pretty good and we were sat promptly.
#
# Unfortunately, I was still feeling a stomach aches that night.
#
# I tried out the "new" meatloaf and it was really bland and so overcooked I had to spit it out. We left immediately after the meal and went to the front.
#
# We went up to the front door and they said there was an order at 12:55, so we waited another 30 min to be seated.
#
# We waited another 15 mins for them to seat us.
#
# After that experience, it would have been in order to get back to the bar.
#
# Our order was not taken until almost an hour. Even this was our second attempt of a food court food court meal. We didn't even finish our first meal.
#
# My wife had a tuna salad and I had a fish and chip meal. My plate was pretty much a pile of food thrown together.
#
# My food was extremely oily and undercooked, as well as my meal.
#
# My steak was overcooked, soggy with lots of gristle and very little taste the fish sauce. Nothing like I expected from a steak and chips place. It was quite obvious to get my food that one portion was just as bad as the other.
#
# The servers were not very quick either, although they were very good to us. I was told that some food courts don't take cash and the other that they don't have to.
#
# Service was extremely slow despite the lack of "supervised" employees.
#
# When we left, I was also told we didn't want to come back...and my wife would never go back either. Never will we go back if that is going to be what they were trying to do to save a business with it's long history here.
#
# I don't know if this is an example of "the customer is always wrong" and how it is all about saving a business or not. I will never know...but I will never try another part of the food court thing. I don't get that.
#
# Not to mention the employees was even less friendly.
#
# Sorry to disappoint you guys now.
# P.s. I wish I could give this place zero stars.<|endoftext|>
# <|startoftext|>This is the second time the service is poor. I waited 30 mins for my food and the lady at the register told me "You're out of food, wait to have another order". I asked to speak to the manager the waitress looked at the register and said "ok, he will be there with you".
#
# When the manager comes down it takes another 5 mins for us to finally come give up and walk out. They gave us a refund.
#
# I am not recommending this place for anything on it's own terms of what it's "The only place in town "
#
# If you decide you can and should go to Denny's or the local Pizza Hut for "The best restaurant on the planet".
#
# Will never ever come back.<|endoftext|>
# <|startoftext|>This is a terrible restaurant. I had never been to a food court or even a fast casual place so was excited to try the food court. After getting our orders, another couple was seated and got their food before we ate. The food wasn't even great and it was like we were at McDonald's for all the food and a cup of ice.
#
# After the server got rid of us and brought us our food, I tried the fish and chips. They were good and the sauce was very interesting. I would have given this place 0 stars if I was allowed. The only positive was our server and some of the food was not served at all.
#
# I
#
# [4105 | 2272.63] loss=3.18 avg=2.99
# [4110 | 2340.85] loss=2.69 avg=2.98
# [4115 | 2409.01] loss=3.10 avg=2.98
# [4120 | 2476.83] loss=3.39 avg=3.00
# [4125 | 2544.50] loss=3.05 avg=3.00
# [4130 | 2614.03] loss=2.93 avg=3.00
# [4135 | 2681.81] loss=2.84 avg=2.99
# [4140 | 2749.86] loss=2.99 avg=2.99
# [4145 | 2817.70] loss=3.32 avg=3.01
# [4150 | 2888.18] loss=2.95 avg=3.00
# [4155 | 2957.67] loss=2.83 avg=3.00
# [4160 | 3026.14] loss=3.13 avg=3.00
# [4165 | 3094.29] loss=3.12 avg=3.01
# [4170 | 3162.80] loss=2.92 avg=3.00
# [4175 | 3231.91] loss=3.05 avg=3.00
# [4180 | 3299.81] loss=2.97 avg=3.00
# [4185 | 3368.20] loss=3.00 avg=3.00
# [4190 | 3437.28] loss=2.49 avg=2.99
# [4195 | 3505.35] loss=2.98 avg=2.99
# [4200 | 3573.77] loss=2.92 avg=2.99
# ======== SAMPLE 1 ========
#  can't
#  I got a whole of it but was willing to call it the way I want to and the last time me just got a whole of it and was not happy.
#
# I'll stick to a better place.
#
#
# Oh and the food is ok but not great. The service is awful, and I should not have to get up to order, just so she can take order, and we all have a few drinks at each table. The bar is a joke, it's just a place in the end, you don't have to take a bar, just so you can get a beer, and a few beers, and then we just sit and chat.<|endoftext|>
# <|startoftext|>I have been to several of the "bar" sites as of now. I had a very limited choice of beer selections, and I was very uninspired during the course of the evening. I found a few of the food (bar and restaurants) to be fairly impressive.
#
# For a "bar" site I think there will be more focus on the beer selection - it was more on the side of the "bar" variety of items.
#
# I was curious about the food quality of the restaurants I visited, and my choice of "bars", or "houses" seemed to fall short by the choice of meats and meats-specific- I had come across at this point. This seems to be a common theme with "bar" sites, so perhaps I'll reevaluate some of their offerings in the coming months.<|endoftext|>
# <|startoftext|>I've been here twice. First time ordered the draft beer and the beer tasted odd, as if it was sitting out for a while. The second visit just another. Same result-I ordered a pint of beer, not a glass--my bill and order both seemed to be off.
#
# The food is just OK so far, but the bartender is very unfriendly and doesn't seem to care much about us.
#
# I'm not sure what, if any, is going on with the place, but the bar and restaurants seemed to be very lacking in terms of quality and service.<|endoftext|>
# <|startoftext|>I thought this time was a real problem. I've visited in the past with no problems. This time there was a slight problem. I didn't touch anything on the menu so I can't remember the exact names of the ingredients I tried to mask in the beer. The staff was very unfriendly and seemed to be mostly interested in making me.  I tried the "beer" and it was the wrong beer. It's not listed on the menu, however if you are a bartender this is probably the reason I tried it.  I will definitely not be returning to this site again.  I was recommended to try the beer and I was told that was very poor quality.  I will not be returning to this particular bar site.<|endoftext|>
# <|startoftext|>I am extremely disappointed at this bar-staffed location. It is literally just across from the grocery store. I will be calling the attention of the managers to ensure they pay proper attention and correct personnel so a proper bar and restaurants can be put into my neighborhood. Unfortunately, I'm not a bar-staff, and I went once, and didn't have issues. I went in Tuesday night, only. There were no staff, and we stood behind the bar. There were only two or 3 people behind the bar, standing at a table. You could tell they were having a great time talking with each other, or that they were not paying any attention when working in the kitchen.
# So I was completely unprofessional while making a drink. I ordered a drink with a large glass of beer. I had an order of wings, I was told.
# The waitress brought back a beer, and then she brought out a half pint beer, and then she brought it back a second half pint beer. (In order to mask my beer theft) My burger remained in the middle of the burger as it was completely untouched. While checking with some of the kitchen staff I noticed that a female (maybe the person's?) behind the bar had been making drinks, but there were only about 7 adults working in a tiny joint.
# I was a waitress during college, and when I didn't have a bartender I was the only one working there, I would come to the bar and say "you would have a better time if I didn't bring your beer."
# I will never return to this establishment again. I hate this place, I just really hate it. I wish there was an option for Zabas and they could be able to work with it.<|endoftext|>
# <|startoftext|>I don't even get it!
#
# I love the idea of a sports-bar
#
# [4205 | 3974.83] loss=2.86 avg=2.98
# [4210 | 4046.09] loss=2.88 avg=2.98
# [4215 | 4118.29] loss=2.81 avg=2.97
# [4220 | 4190.82] loss=3.04 avg=2.98
# [4225 | 4262.46] loss=3.37 avg=2.99
# [4230 | 4334.26] loss=2.82 avg=2.98
# [4235 | 4407.05] loss=3.00 avg=2.98
# [4240 | 4479.76] loss=2.94 avg=2.98
# [4245 | 4551.12] loss=2.94 avg=2.98
# [4250 | 4622.41] loss=2.88 avg=2.98
# [4255 | 4695.13] loss=2.93 avg=2.98
# [4260 | 4768.46] loss=2.14 avg=2.96
# [4265 | 4839.58] loss=2.96 avg=2.96
# [4270 | 4910.59] loss=3.20 avg=2.96
# [4275 | 4981.59] loss=3.14 avg=2.97
# [4280 | 5053.02] loss=2.89 avg=2.96
# [4285 | 5124.89] loss=3.31 avg=2.97
# [4290 | 5196.76] loss=2.91 avg=2.97
# [4295 | 5268.27] loss=2.97 avg=2.97
# [4300 | 5340.10] loss=3.07 avg=2.97
# ======== SAMPLE 1 ========
#  absolutely awful.
#
# We could barely even hear the other employees talk.  The manager was completely oblivious to our request. A huge problem for us.
#
# We have left that establishment after being treated so poorly in the past. I will never spend my hard earned money here again.<|endoftext|>
# <|startoftext|>Terrible. Walked in there on a Monday night and didn't know a bartender at all. When I walked in, the woman was at the register, talking behind her on her phone on a speaker phone. No one said a word to me, not even a hello. I walked in and just went to grab some beer and nothing. The bartender brought out water that had no ice and I guess a can tell a difference between 3 different taps on the wall. I asked for a cold water and was told that that they would not make another one. The first three taps I had were 3/4 full, 2/2 full I am pretty sure. The women there were so rude. I have tried being rude my entire life and I will never be back to this place and I would make you a point to not spend your hard earned money there.<|endoftext|>
# <|startoftext|>I went there today and it was like watching the train wreck that is being written out of a movie. The restaurant has a nice ambiance, the selection of food is decent for what you expect, but you are going to walk out hungry if you don't like the service or food.
#
# The problem is that the service was bad. I ordered the BBQ chicken sandwich (very dry, very dry) and asked to double-dip with BBQ chicken. I was charged for it, but the manager seemed angry when I questioned the charge. I told him that I'm tired of writing review and that I will not be paying $1 for 2 more burgers that come on to my sandwich (this is a one-off charge). I have now been charged almost $17 for just two burgers and he did nothing. Just walked away. I couldn't believe to myself that he is trying to charge me for $17 for two burgers as well. No matter what the total price it would have been no big deal so I know what I am getting. I left the place very unsatisfied. I am just glad I won't be re-visiting this location.<|endoftext|>
# <|startoftext|>I went to here on a Friday night to eat after going to the D.G. for dinner last Saturday and they had the most horrible service I have ever had anywhere!! I was not happy at all because they didn't tell us that our waitress was unavailable! She was standing there with her phone just look at it.. I am actually disgusted!!! I am so lucky that it was such a long line that was waiting there to be seated when I was there I had to wait a bit later. I ordered the "beef" dish. The food came out wrong and the bread was undercooked, overcooked, and it came with the burnt side of potatoes. This is not usually on my list and I usually write reviews with 1 star but I had to try it out cause I was so disappointed. The fries tasted like cheap fried balls with a little bit of BBQ sauce and some veggies.. The burger tasted like burnt brown bread with a little bit of barbecue sauce. I tried calling to rectify the issue and a lady answered the phone saying the owner is here. I asked what the server was saying and I could barely understand her because she was not speaking English!! I asked for the bill and after the lady said the bill will be a few bucks. I asked again and the same waitress told me that's ok and it would be coming when she came.. So i told her and she replied to me "thats how much the bill is" I did not even finish my food and i did not bother waiting for her to call back.. I just left a tip and she never came back to check up on us and to top it off I had 2 young children and she did not even come over to clear the tip. I will not go back and I will tell everyone to avoid this place ever!!!!!<|endoftext|>
# <|startoftext|>Terrible.
#
# The service was terrible. The waitress never asked how things were or asked us how does she want me to do something.
#
# Tried to ask how I wanted it done and what was needed done. The manager(?) said just have the server call me.
# I never got any good responses so I was going to write a review until I got a name and number of the owners. They never called me.
#
# I would never go there again. The food was okay and you'd have to pay extra for the service. The reason I am giving them such a star is because they should be ashamed of themselves for charging what they do here.
#
# [4305 | 5741.98] loss=2.92 avg=2.97
# [4310 | 5813.74] loss=2.97 avg=2.97
# [4315 | 5885.12] loss=2.91 avg=2.97
# [4320 | 5957.47] loss=3.08 avg=2.97
# [4325 | 6030.65] loss=3.06 avg=2.97
# [4330 | 6101.56] loss=2.82 avg=2.97
# [4335 | 6172.13] loss=2.62 avg=2.96
# [4340 | 6242.91] loss=2.97 avg=2.96
# [4345 | 6314.65] loss=2.43 avg=2.95
# [4350 | 6387.92] loss=2.83 avg=2.95
# [4355 | 6459.89] loss=3.39 avg=2.96
# [4360 | 6531.99] loss=2.71 avg=2.96
# [4365 | 6605.61] loss=3.02 avg=2.96
# [4370 | 6680.35] loss=2.68 avg=2.95
# [4375 | 6751.85] loss=2.93 avg=2.95
# [4380 | 6823.31] loss=2.67 avg=2.95
# [4385 | 6895.01] loss=3.15 avg=2.95
# [4390 | 6969.50] loss=3.32 avg=2.96
# [4395 | 7042.90] loss=2.85 avg=2.95
# [4400 | 7114.15] loss=3.02 avg=2.96
# ======== SAMPLE 1 ========
# assed and left a few minutes later. The lady that did not ask was much more apologetic and professional.
#
# I have never tried an AYCE sushi joint, let alone an all out meal and this experience was by far the worst I have ever had! Never again I will ever go there! Not only must I have a group of friends willing to travel there to try this place as in a single day they have the following service,
# - The service is very nice and not overly rude, but they don't need a lot of work. I had to wait a full 10 min for someone to come take our orders, and they forgot to put enough sushi on each of the 4 plates (one order, three orders, two orders)
# - One customer, a single, didn't receive a check for everything that had an "in process " status, and waited an hour to get a check.
# - No one checked the order or even came by to apologize for the wait or any delay.<|endoftext|>
# <|startoftext|>Bought a groupon for our birthday dinner to take out, a day before Christmas and had my boyfriend and my daughter with me to celebrate.  He and I had to wait an hour for our food.  We were the only customers.
#
# This was the worst AYCE sushi I have ever had.<|endoftext|>
# <|startoftext|>We've been eating at AYCE for awhile now.  Got home around 8 and the food was not right.  Took it out and they gave us new food (they took off part of the rice!!?)
#
# The sushi is just mediocre, the meats are tasteless and they are not the cheapest AYCE sushi in the area. We ordered some nigiri and some rolls as an appetizer and a main.
#
# Seaweed salad...
# The rice was bad.  What the lettuce tasted like was lettuce with a bit of salt.  The rice was really bad..
# Wasabi roll was good.
#
# Baked mussels...
# What the mussels tasted like was mussels in water and no salty taste.  The rolls were very bland. The mussels had a nice flavor.  No meat and no meat taste.
#
# Clam tempura, they have a couple of pieces of lobster on the squid.
# These pieces of lobster should be discarded, they were just bad and the squid was not supposed to be so big.  The shrimp was nothing special and the shrimp is very small...
#
# This AYCE sushi joint is not worth the food and it is a real rip off.  Won't be back.  Just bad, really.<|endoftext|>
# <|startoftext|>I haven't been here in a week. I'm still trying to figure out AYCE sushi. We waited at the sushi bar. Only a couple minutes passed. I started to get really sick when I just ate this. I had this food poisoning. And I was super sick so much.<|endoftext|>
# <|startoftext|>We've been here a few times in the last months.
#
# 1st time.
# They were out of rice, so we asked to get a few pieces and we waited around 20 minutes to get my drink from the bartender.
# 2nd time.
# Ordered 3 rolls, I waited over an hour for my food and 2 drinks to come to my table.
# 3rd time. I waited over an hour for my 3 drinks. After an hour, the waitress walked by us and I couldn't stop. My friend and I were not really hungry, but I could not keep my gushy mouth shut. We had to get up and leave as we kept hoping that the 3-4 hour wait was going to get shorter. But we couldn't even get the drinks. We literally had to get up and got our own water bowls.
# 4th time.
# Order a few rolls and we are finally in line. The 3 rolls arrive and they taste so so so. The 4th roll is just a pile of rice. I paid 45 dollars for a roll and I wanted it to be good. I asked the waitress about it and they didn't even say the most helpful thing they could do was send me a new roll of the same size.  I was actually able to tell the lady that if she offered a free roll, she would be better. After this whole ordeal, we finally left hungry just thinking of all of the wait we endured.
#
# Now, a few months later, this was probably my worst AYCE sushi of my entire life, but not by much.
# If they ever try making it again, I'd go. They probably won't be back for a while.
#
# If I could give this place a -10
#
# [4405 | 7517.37] loss=2.87 avg=2.95
# [4410 | 7591.36] loss=3.09 avg=2.96
# [4415 | 7664.73] loss=2.54 avg=2.95
# [4420 | 7735.98] loss=2.79 avg=2.95
# [4425 | 7808.47] loss=3.17 avg=2.95
# [4430 | 7882.08] loss=2.94 avg=2.95
# [4435 | 7953.53] loss=3.11 avg=2.95
# [4440 | 8025.21] loss=2.75 avg=2.95
# [4445 | 8095.96] loss=2.78 avg=2.95
# [4450 | 8166.72] loss=2.89 avg=2.94
# [4455 | 8239.27] loss=2.84 avg=2.94
# [4460 | 8310.94] loss=2.99 avg=2.94
# [4465 | 8383.80] loss=3.17 avg=2.95
# [4470 | 8455.44] loss=3.20 avg=2.95
# [4475 | 8527.81] loss=3.48 avg=2.96
# [4480 | 8600.06] loss=2.95 avg=2.96
# [4485 | 8673.56] loss=2.50 avg=2.95
# [4490 | 8747.36] loss=2.78 avg=2.95
# [4495 | 8822.20] loss=2.49 avg=2.94
# [4500 | 8896.03] loss=2.63 avg=2.94
# ======== SAMPLE 1 ========
# way, we walked up to the counter and asked the bartender if he knew that he was working for a boss. She told him he was here in less than 12 minutes, he looks at her and says "oh wait you must be here for more than 30 minutes". The bartender said "oh" and turns away. You know what? You can't just make me wait a little longer and get a drink...just let me talk. After 30 minutes, the bartender finally stops to take our order...so what did we order? We ordered 3 different beers: pale, dark, and amber. We were given a very basic beer selection, they obviously just put some alcohol in and they don't have a lot of beer selection. We asked for a glass of sangria for our 6th of our order...it looked like they had just placed our order and were just drinking it...we're just waiting for our server to come back to pick up our order. Another patron at our table had the same experience, he was served a pint...I guess the only reason we got our check was because someone had called us and they were able to figure it together...the only beer they had in stock was the black one...I don't know if I would recommend this place for food, drinks, or even beer...this is the worst server I have met in Montreal! This is not the type of staff you want working at a restaurant as a waiter or waitress...not the type of server you want working a customer place! Do yourselves a favor, find a place where you get to have a drink on their own! I would suggest the food court located by the fountain...
#
# Oh and don't plan on making a reservation after midnight (it will be closed during prime time), it will not be even a good estimate. It's not even worth the wait as the service is very slow, especially when they only have you waiting 30 minutes.
#
# This place is a joke and will never return.
#
# I hope this review will make it clear that this is a restaurant with a big difference from the one that I had a very similar positive experience at on the strip in 2013...you need a reservation to be served....the place is empty and you can't even order food or drinks....a place like this should be shut down.
#
# Oh, one more thing...don't feel sorry for the bartenders when they are just standing there...as they have no line, they have no drinks, the servers are just standing all over the place, and no one actually has a clue how to take a simple drink order...no one even seems to know how to handle the issue. And at one point I feel like I was being mocked and laughed at by the bartender...I don't think anyone should be standing at a bar and just stand there. At the end, there was no one even acknowledged that I stood there.
#
# When I finally had one of the servers come back, he asked me what I'd like to drink...not because I was ordering a beer! He didn't even serve my beer because the bartender never came over? Then he says to me "ok, we'll take that". Ok, I take it back...and they never refilled my beer. When I ask what he was doing next, I was just wondering where he was. Now he's calling me "crazy". I'm pretty sure that was a reference to me being a customer waiting for my beer at the bar. What about me just sitting there in the same place that's sitting empty on midnight and not even been given my beer yet? I'm just curious if he thought that he would get more tips as he's not giving a single cent...the people he's served?
# So for reference, this place is a nightmare with no food on the menu. You may be better off going to another bar for lunch. And I'm definitely coming back soon...there's no excuse for the lack of service and the poor management on their part!<|endoftext|>
# <|startoftext|>This place went from a 5 star to a 1 star because of the extremely unfriendly service that we had from the bar staff.  We had been trying to catch in with the large party we had at a party in C-c-c-C-I-c-C on Friday.  Not so easy.  We arrived at 5:45 and the hostess informed us that they don't take reservations. There is no wait, they have an empty parking lot, so we left.   Will not be coming back.<|endoftext|>
# <|startoftext|>This was the most horrible experience we have ever had at a restaurant.   What happened to customer service?  The hostess was rude, and never checked on us despite that she took our reservation. We waited almost 20 minutes before our drinks were taken (before we asked several times about a manager).  We then asked to get
#
# [4505 | 9301.03] loss=3.21 avg=2.94
# [4510 | 9373.64] loss=2.97 avg=2.94
# [4515 | 9445.88] loss=2.61 avg=2.94
# [4520 | 9518.35] loss=3.01 avg=2.94
# [4525 | 9591.17] loss=3.17 avg=2.94
# [4530 | 9663.02] loss=3.13 avg=2.94
# [4535 | 9734.04] loss=3.19 avg=2.95
# [4540 | 9806.47] loss=3.00 avg=2.95
# [4545 | 9879.12] loss=2.84 avg=2.95
# [4550 | 9950.93] loss=2.66 avg=2.94
# [4555 | 10021.98] loss=2.94 avg=2.94
# [4560 | 10095.88] loss=2.86 avg=2.94
# [4565 | 10167.85] loss=2.30 avg=2.93
# [4570 | 10241.94] loss=2.89 avg=2.93
# [4575 | 10314.33] loss=2.94 avg=2.93
# [4580 | 10387.10] loss=3.51 avg=2.94
# [4585 | 10460.00] loss=3.08 avg=2.94
# [4590 | 10531.56] loss=2.83 avg=2.94
# [4595 | 10603.85] loss=3.13 avg=2.94
# [4600 | 10679.95] loss=2.64 avg=2.94
# ======== SAMPLE 1 ========
#  keep up with a lot of our orders.
#
# If you have no way to do business, don't bother paying so they can get a bigger crew or better run their business.
#
# I have done business with them before, and they were not as great in the past.
#
# I won't be back to any of their restaurants.<|endoftext|>
# <|startoftext|>A business should never turn away a customer and I don't think they have.  To start, there was little to no sign and no one. It seems like a place run by children.
#
# We are in Las Vegas for one and we made reservations at the hotel and the hotel. The sign was hanging on the hotel door and when we got to a place, the sign didn't say where to look at, it just said to look at the sign. So for my husband we were headed for a Vegas experience.  We made reservations and as we were getting to the check in to an airport, I looked around the hotel. I noticed that they were closing in the hotel as well and I was not that pleased with a business that refuses to turn on a light in their hotel. The last night at the hotel, there was a light going and I could see them. It was the worst experience ever.
#
# Once the hotel is closed they should close the light.
#
# No hotel was open but this business didn't exist at the time we were there for our Vegas experience. The business wasn't that busy. It was really busy in the lounge and they were still open. They were not closing down early.  I have worked in retail for years and I have seen so many different businesses survive because they are so busy. This isn't one of them.
#
# They had other guests that stayed for a few nights or weekends that came in after the hotel was closed. They didn't have anything there but that was the only place open at 9.
#
# I think the owner should be aware that the business was closed.  They were not busy. We were the only customers in the lounge and the lounge wasn't even that packed.  I don't like that other guests are treated this way by the staff for a fun night out and about.   One guest got there and I was a customer and waited until 10pm for our hotel to open and I was late for work. Now they don't have a sign for it or the right signs and they have had guests come in after hours as well.  They have had guest sit in booths.  We can understand that and we can still be a little upset. They need more people.  We can be nice.  We can even try to be respectful.  We understand if you do not have a sign.  However, after the customer has walked in to the lounge, left and walked up to someone you need to know that you need to change the sign.  There was nothing said in our hotel or the lounge anywhere else.  That's what they did.  So they took off the sign.   They closed for the night and it was 9:30 in the morning.  I thought I would not have a problem with that but it was late.  So that is just one little thing.  We still went there early to catch them closing early but it was 11 and we said we were here for breakfast. I think the only thing I understand was that they need to change the sign.  They have to change it.<|endoftext|>
# <|startoftext|>The place is great but the bartender is rude and unfriendly.<|endoftext|>
# <|startoftext|>Not sure I understand why this is a 4/5 place to a 5 star business. The food is decent for the price. But all of the other things I had here were poor at best and if you go to the bar and they don't make you a drink. What makes sense is why have all these drinks when you need a drink at your table. I mean that's not right. Especially now that you're a "premiere" place.
#
# I know for sure now that I will not go back. The restaurant is packed and they don't even have enough staff to work the restaurant.<|endoftext|>
# <|startoftext|>A very disappointed experience.
#
# The service was horrible.
#
# The food was mediocre.
#
# We ordered the specialties (Kiwi and Red Velvet) and the red velvet was not fresh at all. The Red Velvet was dry with very mild pepper.
#
# I ordered a salad to share with a friend. I had to ask for a salad.
#
# The salad was a hot mess. It tasted like it was heated in a frying pan. I was extremely dissatisfied with this place and will never come back.<|endoftext|>
# <|startof
#
# [4605 | 11081.95] loss=3.20 avg=2.94
# [4610 | 11153.79] loss=3.14 avg=2.95
# [4615 | 11224.90] loss=3.07 avg=2.95
# [4620 | 11296.85] loss=2.99 avg=2.95
# [4625 | 11367.95] loss=3.08 avg=2.95
# [4630 | 11439.78] loss=2.74 avg=2.95
# [4635 | 11513.91] loss=2.86 avg=2.95
# [4640 | 11587.67] loss=2.38 avg=2.94
# [4645 | 11662.77] loss=3.12 avg=2.94
# [4650 | 11738.45] loss=3.21 avg=2.94
# [4655 | 11811.58] loss=2.80 avg=2.94
# [4660 | 11883.73] loss=2.71 avg=2.94
# [4665 | 11957.35] loss=3.01 avg=2.94
# [4670 | 12029.21] loss=2.90 avg=2.94
# [4675 | 12102.49] loss=3.38 avg=2.95
# [4680 | 12174.12] loss=3.12 avg=2.95
# [4685 | 12246.29] loss=2.83 avg=2.95
# [4690 | 12316.85] loss=2.73 avg=2.94
# [4695 | 12388.47] loss=3.18 avg=2.95
# [4700 | 12459.75] loss=2.96 avg=2.95
# ======== SAMPLE 1 ========
#  back that day, I was already on my way out...I asked where does the manager work, and she didn't know who to tell. She's a nice lady, and she said she wanted this out, and that was a nice girl's job.
# I left with only one card. I gave them $25 off, and that was the only time I did not give a credit card.
#
# I was extremely disappointed. I will not return.  I'm done giving BBB and BBP my business. They are so slow. I will stick with them.
#
# The only thing I like about BBB is that they take your cash to buy gift cards for the customers over there.<|endoftext|>
# <|startoftext|>Do not go here! They will steal your cash from you, and they are unable to verify your account status in the event your account is declined.
# We went to the store and the manager was literally in the back doing something in which I didn't know right, but he looked at us and said "they don't need your debit card".
# The manager said "what do you want me to do about it? I haven't taken your debit card yet so all they can do is check it".
# Well it's not like they were busy, they were only a few people with no help.
#
# He has lost a customer over there for life and now he need to be a part of the customer.
# The manager needs to be friendly, and he needs to start giving customer service.
# Do not give BBB and BBP your business!
#
# We don't know how this store stays in business, they obviously steal from every time we go there.
# The manager needs to have friendly, and he needs to start giving customer service!
#
# We have been in this store numerous times and the manager never gives customer service. It's disgusting how this store stays in business and they are just doing things the way they want to do them.
#
# It's no longer a bbb or bc. store, we are gone, we will never return. BBB and BBP should take our money and treat people, and their banks, with care!<|endoftext|>
# <|startoftext|>They are very disorganized. They did have a good selection, but it is not as good as a grocery store. For a store that charges your credit card, they must be good at managing their customer who will come and come back. If a staff member is not doing their job, you have to be good at managing other people who are around you.<|endoftext|>
# <|startoftext|>The staff that work here are very unfriendly and rude. The manager is rude to his own people. I worked at a coffee shop before and now I know customer service as well. You are better off walking out when you can.<|endoftext|>
# <|startoftext|>The place is run like a zoo with little respect...I've waited forever to put my name on the list.  The last 6 times I've called for my appointment, I've asked to speak to someone else and they have told me you are now in the past week.  Finally once the girl answered she was on her way to the back of the store.  Once she came back on the phone she said you have to let me know. Which was fine with me because she was one of the more friendly voices on the phone. The last visit was one of the worst call I've ever had.  They cancelled my appointment for the first time ever and that was a good thing.  I was upset and tired by the time I was ready to go home I was completely furious. I called the store several times a month to check it but I've been in town for the past 2 years, for almost 3 years now I haven't seen anyone that can speak Spanish on a Sunday.  I've been to the store several times for the next 2 years and they weren't open all this time.  So I called on a Saturday afternoon at 11 PM to speak to the girl and she had answered multiple times and they were open.  The woman on the phone said she was sorry but people are always on it and that's the last you give.  She didn't even try to apologize.  I understand that she is the manager, but she should have listened to her employees in the beginning and she should have told them. She didn't.  I wouldn't care if she was a nice person but if someone from the back or the company knew the phone number and called for the number. The woman on the phone acted annoyed.  She took my number and I didn't make the decision.  The customer service she was doing at the restaurant she left.  The people that don't care. They didn't work there.<|endoftext|>
#
# [4705 | 12860.76] loss=3.15 avg=2.95
# [4710 | 12933.18] loss=2.50 avg=2.94
# [4715 | 13006.78] loss=2.84 avg=2.94
# [4720 | 13080.29] loss=3.31 avg=2.95
# [4725 | 13152.03] loss=2.94 avg=2.95
# [4730 | 13223.77] loss=2.95 avg=2.95
# [4735 | 13297.26] loss=3.18 avg=2.95
# [4740 | 13369.28] loss=3.17 avg=2.95
# [4745 | 13440.30] loss=2.83 avg=2.95
# [4750 | 13511.59] loss=2.70 avg=2.95
# [4755 | 13582.28] loss=2.40 avg=2.94
# [4760 | 13652.90] loss=2.69 avg=2.94
# [4765 | 13724.67] loss=3.11 avg=2.94
# [4770 | 13796.81] loss=3.41 avg=2.95
# [4775 | 13868.11] loss=3.06 avg=2.95
# [4780 | 13940.99] loss=2.60 avg=2.94
# [4785 | 14012.26] loss=2.68 avg=2.94
# [4790 | 14082.70] loss=3.01 avg=2.94
# [4795 | 14154.51] loss=2.65 avg=2.94
# [4800 | 14225.45] loss=3.30 avg=2.94
# ======== SAMPLE 1 ========
#  a not so nice way to say it with an accent. I asked her nicely to give me another beer - she took the beer and refused to bring me a new one. I did not want the server to take the beer and leave. She was rude and very condescending.
#
# The food was mediocre for the price. My girlfriend ordered the steak, egg, and bacon sandwich and it was nothing like it used to be. I can't really tell you what was good, or not bad.
#
# Our waiter was nice and the place clean, even if it is not what you think it is. I had to remind the waiter to refill our glasses of water to avoid it, but that's not a big deal, unless you really value that much. The bill came and I was in the middle of the conversation with the manager before my new server came to our table and I asked if it was OK to split the bill and a manager asked me about it. She was nice. That is how it is always been, always bad.
#
#  We were the only non-white people in the restaurant - another couple seated that looked to be Caucasian. The waitress came over and asked if everything was ok. I said yes and we were on the way out. I explained the situation and her response was "I don't know what you want" - I know, it is awkward, but I don't give up on this guy just yet.
#
# I wish I could give it less stars. I can't even get that though because I don't see a manager that comes to talk with us or anyone else there.
#
# The manager came by and told me if I wanted a discount in my tab or the kitchen manager's card I could bring it in and give it to them. I told the manager politely that our experience was poor and he had just told me what he thought.
#
# Then there is this exchange about the table next to us and how I would feel about moving them: She's like...the manager should think twice and if they think about it they would say no. I felt that was unfair to the table next to us.
#
# I do not eat the same food my girlfriend and I do so I have no idea how our waiter had his life ruined. I feel like he should be fired like all the white males are so they can be a good race-based restaurant.<|endoftext|>
# <|startoftext|>I really like here and always have good service. This time the service was TERRIBLE!!! So I am very disappointed with the way the waiter ran their tip. I can only tell you the waiter left 40 tips on the table after my friends complained. They had no problem with it and didn't complain. But that's disgusting service. Plus we got a discount on the table. The waiter came back 4 minutes after we had left to tell us we had to leave. They were still there... They were so upset... I really feel stupid, I can't believe they got a discount after complaining. Shame on the waiter!!!<|endoftext|>
# <|startoftext|>Went for the food with my mom. Service was great. I love this place. I didn't realize when you order from here it is so much more expensive. No matter what time of day. No thank you.
#
# When you order, the server will say, "the check is about to be handed to you" I asked them for a half of their entrees. I never got told what they were. I did not get a check. I do not know if that's a requirement for customers or the waiter thought we weren't paying full price for our entrees, but it was ridiculous. I didn't want to bother the waiter and then get a refund because he didn't know what his job was. So I paid and got my order. But then, as I paid they left a 20% service charge. I felt like shit that didn't do me any good.
#
# And as a note to the owners, get a freaking check!!!!!!<|endoftext|>
# <|startoftext|>This is the worst seafood seafood place ever in Toronto. The food is super bland, the service is horrendous, and the staff was so rude on the food. It was one of those dimly lit nights, but the whole restaurant was a huge fail.
#
# I wanted to order from here on a Saturday morning and they told me all of their Seafood bowls are $5.85. Well, guess what? This was $7.50 a bowl. I don't know how you can run out of food that you were told they were going to get? I have worked as a waiter in the service industry, but guess what? If you only offer one dish per table, that's fine. What I do not know is how the owner can afford to sell $1 of every dish for
#
# [4805 | 14627.53] loss=3.22 avg=2.94
# [4810 | 14700.22] loss=2.84 avg=2.94
# [4815 | 14771.99] loss=2.55 avg=2.94
# [4820 | 14843.95] loss=3.21 avg=2.94
# [4825 | 14917.13] loss=2.92 avg=2.94
# [4830 | 14990.48] loss=2.59 avg=2.94
# [4835 | 15062.45] loss=2.25 avg=2.93
# [4840 | 15133.90] loss=2.91 avg=2.93
# [4845 | 15205.68] loss=3.12 avg=2.93
# [4850 | 15276.92] loss=3.05 avg=2.93
# [4855 | 15348.69] loss=2.86 avg=2.93
# [4860 | 15419.67] loss=3.00 avg=2.93
# [4865 | 15490.99] loss=2.73 avg=2.93
# [4870 | 15562.29] loss=3.06 avg=2.93
# [4875 | 15636.46] loss=2.82 avg=2.93
# [4880 | 15710.97] loss=3.13 avg=2.93
# [4885 | 15786.31] loss=3.62 avg=2.94
# [4890 | 15859.32] loss=3.13 avg=2.94
# [4895 | 15933.29] loss=3.27 avg=2.95
# [4900 | 16006.27] loss=3.09 avg=2.95
# ======== SAMPLE 1 ========
#  service.  This place has lots of potential to add to it and that's just the start.<|endoftext|>
# <|startoftext|>Horrible Service. Called it in for a dinner special; it was at 10pm and we had an hour to prepare our dinner. When we called in we were put on hold for 3 minutes; and then the person on the phone said that it was going to be ready in a few minutes. When finally the order came, the waitress (with the long curly hair) said it was a special that was not included with entrees; therefore the order was not included. She also said they no do take out orders at the time they are told to not take out food to go; but we asked her if she was aware the dish was not included in the special menu until we told them. She said that they had not decided on it for us, and that there were no specials being made today. She also said we were at lunchtime, and they said that there was nothing she could do and had no idea what it might be.
#
# There was also a very rude guy at the counter waiting on his phone and was extremely defensive when we told him about our terrible experience; the guy was so snobby, and said that it was just a regular. We went back to our table, sat in the dining area, and had a pleasant dinner as I'm pretty lenient, and when that guy saw us leave, he quickly stood up, rudely apologized and said they were busy.
#
# This place was awful for such a nice day, and we will no longer call it a business.<|endoftext|>
# <|startoftext|>I wish I had read this before I ordered the $14 chicken fried rice and I thought I would give this place one star. The reviews are quite accurate in their description of the restaurant. My order included one chicken fried rice each, rice, and a small chicken dish with rice. I wanted to put it on the order pad (I ordered a small dish which I paid for in my order) for a better value. I decided not to give the restaurant a star but one star is a perfect reflection of their terrible customer service.
#
# I will say this the service at the restaurant was very friendly. While I was eating my dish, I could hear the two young girls at the register calling some more customers that walked in the door, and laughing and calling back. I asked the cashier girl about it and she told me it was nothing and nothing came to mind. After I got an earful of how bad they were, I had enough and called the restaurant. I was given the phone number to reach out to customer service and was given a phone that was full of very rude messages. I was very disappointed with the location's poor customer service.<|endoftext|>
# <|startoftext|>I really enjoyed our take-out dinner here. The service by the woman was horrible!! To the point I would almost walk out. She was too busy with the phone to acknowledge us. If the food isn't good, then it's not worth my time to call them.<|endoftext|>
# <|startoftext|>The one star that is being given not to review the food but the service! This is probably the only real review but we don't know if its to be good, but if its going to be the same and good food, I don't think there should be a rating like this.
#
# We had dinner here. First of all, it's close to home, we ordered a dinner, our food was cold and was not prepared by our server, but it was fairly tasty. The service, however, was completely lacking. I've never been the only server in the front, and as we were paying, one waitress seemed very confused about the menu, no one checked up on us to make sure our food was ready for our tables to get there. It was also raining and my husband waited till the weather got wet, and that was my fault.
#
# The waitress didn't take our order until she dropped off the food. At first we thought this could be a big deal, but after our meal, it seemed to be quite typical of other times we paid. The service, however, was very sloppy, and the food was just ok.
#
# The food is soo expensive.
#
# This place is like my wife's (and the food is the same as our old one)!
#
# I will not be returning.<|endoftext|>
# <|startoftext|>After visiting a McDonalds I have always been told that their hamburger is delicious as I believe their sauce is delicious.
#
# Now, a couple of months have passed and we ordered a meal with cheese on the side of chicken and fries. My burger was extremely bland and so was my fries. After we called to speak to
#
# [4905 | 16409.17] loss=2.63 avg=2.94
# [4910 | 16483.11] loss=3.05 avg=2.95
# [4915 | 16556.73] loss=2.86 avg=2.95
# [4920 | 16629.20] loss=3.12 avg=2.95
# [4925 | 16700.80] loss=3.03 avg=2.95
# [4930 | 16772.13] loss=3.07 avg=2.95
# [4935 | 16844.26] loss=2.74 avg=2.95
# [4940 | 16915.75] loss=2.88 avg=2.95
# [4945 | 16987.05] loss=2.99 avg=2.95
# [4950 | 17059.29] loss=2.95 avg=2.95
# [4955 | 17131.25] loss=2.76 avg=2.94
# [4960 | 17201.84] loss=3.18 avg=2.95
# [4965 | 17273.62] loss=2.76 avg=2.95
# [4970 | 17344.77] loss=2.80 avg=2.94
# [4975 | 17416.64] loss=3.07 avg=2.95
# [4980 | 17490.63] loss=3.21 avg=2.95
# [4985 | 17562.77] loss=2.92 avg=2.95
# [4990 | 17634.90] loss=2.76 avg=2.95
# [4995 | 17709.31] loss=2.94 avg=2.95
# [5000 | 17783.59] loss=3.17 avg=2.95
# Saving checkpoint/review_star_1_large_food/model-5000
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-9c68c8dcc572> in <module>()
#      16               print_every = 5)   # steps is max number of training steps
#      17
# ---> 18 gpt2.generate(sess)
#      19
#      20
#
# /usr/local/lib/python3.6/dist-packages/gpt_2_simple/gpt_2.py in generate(sess, run_name, checkpoint_dir, model_name, model_dir, sample_dir, return_as_list, truncate, destination_path, sample_delim, prefix, seed, nsamples, batch_size, length, temperature, top_k, top_p, include_prefix)
#     439         checkpoint_path = os.path.join(checkpoint_dir, run_name)
#     440
# --> 441     enc = encoder.get_encoder(checkpoint_path)
#     442     hparams = model.default_hparams()
#     443     with open(os.path.join(checkpoint_path, 'hparams.json')) as f:
#
# /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/encoder.py in get_encoder(checkpoint_path)
#     107
#     108 def get_encoder(checkpoint_path):
# --> 109     with open(os.path.join(checkpoint_path, 'encoder.json'), 'r') as f:
#     110         encoder = json.load(f)
#     111     with open(os.path.join(checkpoint_path, 'vocab.bpe'), 'r', encoding="utf-8") as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoint/run1/encoder.json'

# %%
# reset session so that can prepare for text generation 

gpt2.reset_session(sess)

# %%
# start new tf session for text generation

sess = gpt2.start_tf_sess()

# %% [markdown]
# ### ************ End of Training ************
#
# ---

# %% [markdown]
# ### **Generate Results for Review Star 1**

# %%
gpt2.load_gpt2(sess, run_name='review_star_1_large')
# Out:
# Loading checkpoint checkpoint/review_star_1_large/model-11000
# INFO:tensorflow:Restoring parameters from checkpoint/review_star_1_large/model-11000

# %%
gpt2.generate(sess, run_name= 'review_star_1_large', length=100, prefix= "The food here is", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# The food here is  disgusting. I'm not saying I don't like the food but maybe if I was starving I wouldnt have a complaint about it but coming from the other side of the town this is in the middle of my neighborhood. It has no flavor to it. It is just bland. The cheese is too hard and the beef is bland. The buffalo sauce is so salty and way too thick. The chicken is so dry that I can't even eat it. The nachos are sooooo slim.

# %%
gpt2.generate(sess, run_name= 'review_star_1_large', length=100, prefix= "The food here is", sample_delim = '<|endoftext|>', include_prefix=False, nsamples=5)
# Out:
# The food here is great and the staff are very friendly and welcoming but I felt like the management staff was never there. I would ask for my bill and they would take it for me, I would come back and they say we need to talk to the manager. It is not like I was being a problem. The manager was never there and I would ask for my bill for him for a week or so. If I had any problems I would always let them know, but it was never addressed. I felt that
# <|endoftext|>The food here is not worth the money. The portions are small and the quality is terrible. If you are looking for a good Chinese restaurant, do not come here.<|endoftext|>
# <|startoftext|>They charge you $10 to use their food trucks. The trucks are delivered to your house.
#
# The food is garbage. The fries tasted bad. The lack of salsa and sauces were minimal. The food truck is a clusterfuck of unorganized mess. If you are
# <|endoftext|>The food here is terrible. This is a restaurant that the management has a really bad attitude. If you want to eat here, avoid it at all costs.<|endoftext|>
# <|startoftext|>HBs is NOT one of the original Five Guys in Las Vegas. EVER.
#
# The employee (Carol) at this location has an attitude and doesn't seem to care about her job. I witnessed her being rude to a manager because she was rude to him because he was
# <|endoftext|>The food here is awful. It's a shame they are not doing anything about the situation, because the restaurant is located right next to IKEA. The manager is great, but the food is not good.<|endoftext|>
# <|startoftext|>I just decided to go to the new location instead of the old one. The food is sooo bad! It was almost like you could smell it as you tried to eat it. It was so bad that I had the food taken
# <|endoftext|>The food here is decent but the service is awful. I had to wait 30 minutes to get my order of chicken wings, and when I finally got it, it was very soggy. I was then told that they did not have a new recipe but could make chicken wings with the old recipe. I was then told that I could return the wings for a discount if I went back to my original order.
#
# This is a terrible restaurant to go to. Don't go here.<|endoftext
# <|endoftext|>

# %%
gpt2.generate(sess, run_name= 'review_star_1_large', length=100, prefix= "I like the", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# I like the experience.
#
# I was not happy with the decor of this place. I got the 'Chicharones' that are my favorite things in heaven. I am very picky and I would not order more than three, but I could try the three. The 'Chicharones' are a classic form of Mexican cheese, so I am a bit annoyed about the fact that I can only get one. The cheese is a bit more than I would like, as it was dry and

# %%
gpt2.generate(sess, run_name= 'review_star_1_large', length=100, prefix= "I hate the", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# I hate the dentist.  Despite being in Vegas for over a decade, I've never had a dentist that I enjoyed going to.  But Dr. Rene is so patient and kind.  And she really takes the time to talk to you.  Dr. Rene is very thorough and I always leave happy!  She puts the proper amount of stress on you.
#
# I also love the fact that she is a non profit dental group.  And I am very happy with the pricing

# %% [markdown]
# ### **Generate Results for Review Star 5**

# %%
gpt2.load_gpt2(sess, run_name='review_star_5_large')
# Out:
# Loading checkpoint checkpoint/review_star_5_large/model-5000
# INFO:tensorflow:Restoring parameters from checkpoint/review_star_5_large/model-5000

# %%
gpt2.generate(sess, run_name= 'review_star_1_large', length=100, prefix= "The food here is", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# The food here is so good! They have all the traditional Chinese food, but they'll also give you more Japanese style dishes/sashimi food. They have a lot of different kinds of green tea beers and several different types of sushi, sashimi, and some spicy tuna. The sushi is fresh and yummy. The fish is fresh and the rolls are crispy. The jalapeno tuna is very light and soft. The green tea flavors are off-putting.
#
# They have a

# %%
gpt2.generate(sess, run_name= 'review_star_1_large', length=100, prefix= "The food here is", sample_delim = '<|endoftext|>', include_prefix=False, nsamples=5)
# Out:
# The food here is consistently good and consistent. I'm a fan and recommend you go if you're in the area.<|endoftext|>
# <|startoftext|>I've been to this place a few times, and I love the service. The waitress did not make me feel uncomfortable. I ordered the chicken parmigiana and it was AMAZING! The sauce is just the right amount of sweet. The chicken is crispy and tender. The steak is good quality as well. My
# <|endoftext|>The food here is absolutely delicious!  The salmon was tender and flavorful and the garlic breading was perfect.  I had the seasonal carrot and dill chutney and it was deliciously sweet and tart.  I'm not really a fan of sweet things but I loved every bite of these delicious pcs.  The dill and dill chutney combined are delicious and the potato salad was refreshing.  I finished my bowl with a side of rice noodles.  I was impressed as well as my
# <|endoftext|>The food here is delicious and the service is great.
#
# I've eaten here maybe 8 times since I've been here, and I've never been disappointed.
#
# The service was fast and the food was good.
#
# I would love to try the soup, but I'm not sure what I'll be getting next time.<|endoftext|>
# <|startoftext|>He was good. No one can beat the price.  He was on time
# <|endoftext|>The food here is very good, and the service is excellent. The place has a very nice walk-in philosophy, and they give you a paper menu as you walk in, which is a nice change from most places that have you walk out of the door.
#
# I have not had a bad meal here, and I have been here for any occasion I have been to, from a family dinner or business meeting to a business meeting. I have been a fan of their vegan peanut butter, and I enjoy
# <|endoftext|>The food here is excellent, and I really hope that a location in LA will be the same as they are in Las Vegas. For more information on the location, check out the location in Vegas.<|endoftext|>
# <|startoftext|>I went to this restaurant for the first time and I was very happy with the service. The food was excellent and the service was fast. I will definitely be back!<|endoftext|>
# <|startoftext|>I
# <|endoftext|>

# %%
gpt2.generate(sess, run_name= 'review_star_5_large', length=100, prefix= "I like the", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# I like the ice cream and I like the peanut butter. I like that they have the chocolate and strawberry flavor. I think I will get that next time.
#
# The only drawback is the parking lot is a bit small. I could definitely get a spot.<|endoftext|>
# <|startoftext|>I have been looking for a new one for about 2 years now and I can't believe I haven't yet. I went to a couple places before I found this place and every

# %%
gpt2.generate(sess, run_name= 'review_star_5_large', length=100, prefix= "I hate the", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# I hate the "cutesy" and ugly plastic surgery in dentistry, but then again, most of the dentists I've seen are very distant relatives so I'm glad I got to have my crowns removed! They replaced the crowns and the crowns are awesome! A little more permanent and less in a long time period!
#
# The staff are professional, very friendly and informative. They have her own suite which is very nice, and has everything you could need. The room is surprisingly clean

# %% [markdown]
# ### **Generate Results for Review Star 1 Food**

# %%
gpt2.reset_session(sess)
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='review_star_1_large_food')
# Out:
# Loading checkpoint checkpoint/review_star_1_large_food/model-5000
# INFO:tensorflow:Restoring parameters from checkpoint/review_star_1_large_food/model-5000

# %%
gpt2.generate(sess, run_name= 'review_star_1_large_food', length=100, prefix= "The food here is", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# The food here is the worst I have ever had and the service is too awful as well. The manager has no idea of customer service and it's usually not that great. I would not recommend this place to anyone.<|endoftext|>
# <|startoftext|>Very disappointed.
#
# Went there for lunch.  The place was busy but we didn't feel rushed at all.   The food was not good.   I had the spicy shrimp, the texture was

# %%
gpt2.generate(sess, run_name= 'review_star_1_large_food', length=100, prefix= "The food here is", sample_delim = '<|endoftext|>', include_prefix=False, nsamples=5)
# Out:
# The food here is pretty good, but I have eaten way better at Subway, and the vegetarian options are not so good.
#
# I have been to a lot of grocery stores and have never been disappointed by the food here.
#
# I don't think I will be back, but except for the food, the shopping experience is pretty bad.
#
# I would not recommend this store to anyone I know.<|endoftext|>
# <|startoftext|>This place is not open for lunch
# <|endoftext|>The food here is pretty bad, and not worth the $30 to $40 per person (or more) you need to bring here.  For the price, the food is not much better than most other places, but the service is totally unacceptable.  For an $30 to $40 per person (or more), we are expecting a better experience.  Only the food and service here will spoil the reputation of this place, and we will never return.<|endoftext|>
# <|startof
# <|endoftext|>The food here is garbage. I had the chicken parmigiana which was a little dry and tasteless. The service was terrible. I would not recommend this place to anyone.<|endoftext|>
# <|startoftext|>I wanted to like this place but they only have 10 pieces of chicken left on their menu. The manager told me that they don't have enough chicken for 10 pieces. I understand if it's busy, but when I went there to order it, they didn't
# <|endoftext|>The food here is good, but the service is a downer to me.<|endoftext|>
# <|startoftext|>This is the worst restaurant in the city, I had a reservation for 7:15pm on a Wednesday. Called the restaurant at 7:40pm and the hostess said she was behind on the order. I called back at 8:10pm and the hostess said she was behind on some orders. I called back at 9:30pm and she stated that
# <|endoftext|>The food here is overpriced.
#
# If you want to pay $20 for a Mushroom soup and bread, there is no way in hell that you are going to get that.
#
# Soup is very small and miserable, bread is tasteless.
#
# Two people that I had the wrong order and my boyfriend that had some very very bad food that day came back and said he was very sick for the next few days.
#
# I will never be back.
# <|endoftext|>

# %%
gpt2.generate(sess, run_name= 'review_star_1_large_food', length=100, prefix= "I like the", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# I like the food and I am very picky about my food. I will say that the place is clean and the service was good but I will not be returning.<|endoftext|>
# <|startoftext|>I have been a loyal customer for 3 years now. I have been a first time guest and tried many different places and no one has the same experience as the last time. This time, with the last two visits I have been disappointed and this time the last time was their

# %%
gpt2.generate(sess, run_name= 'review_star_1_large_food', length=100, prefix= "I hate the", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# I hate the idea of unnecessary "goufs" with a bar/club atmosphere.  But I can't get past it.
#
# It's my friend's last night in Vegas.  The whole time we've been here, we've had the worst memories.  And I'm beginning to wonder why.
#
# We went back in.  This time, the security guard at the door (who was wearing a black tank) came out.  He threw both in the

# %% [markdown]
# ### **Generate Results for Review Star 5 Food**

# %%
gpt2.reset_session(sess)
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='review_star_5_large_food')
# Out:
# Loading checkpoint checkpoint/review_star_5_large_food/model-5000
# INFO:tensorflow:Restoring parameters from checkpoint/review_star_5_large_food/model-5000

# %%
gpt2.generate(sess, run_name= 'review_star_5_large_food', length=100, prefix= "The food here is", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# The food here is really good. The menu is pretty extensive and it's a great place to do a date or to grab the wife's half of a dessert. Great atmosphere and great service. The food here is pretty good and the staff is friendly. They have some really good deals on the menu... especially the fries. These fries are cooked perfectly and have a mouth feel to them. They are awesome and I would definitely come back here just for the fries. I love the combo of the french fries with the 2

# %%
gpt2.generate(sess, run_name= 'review_star_5_large_food', length=100, prefix= "The food here is", sample_delim = '<|endoftext|>', include_prefix=False, nsamples=5)
# Out:
# The food here is awesome and the service is wonderful. I love the classic veggie burger and the cheese fries are to die for. The atmosphere is casual and welcoming and the food is exceptional. The owner is amazing and still has it touch of hipster in his style.
#
# I'm so glad we stopped by and I can't wait to go back. I've been wanting to try the Golden Nugget for a long time but it always seems like a drive and a half away, so we decided to stop
# <|endoftext|>The food here is authentic and delicious.  My daughter loves the wonton soup.  We always get the chicken teri (usually with tofu, or with beef, or with chicken).  The broth is fast, the chicken is juicy and the noodles are perfect.  The rice is really good.
#
# I can't get enough of the hot chicken.  And a couple more times I've been there, and I've eaten the whole bowl of chicken, and it's still super tender.  It's
# <|endoftext|>The food here is outstanding. I first started coming here in December when they were open and recently we've been back a few times since. The food is fresh and the staff is super friendly. They don't rush you and they are always very attentive. The prices are very good. Try their kimchi fried rice and the rice and veggies are also very good.<|endoftext|>
# <|startoftext|>I've been coming to Aji for two years now for the most part -
# <|endoftext|>The food here is amazing! The staff is awesome and the owners are amazing. You could spend hours here and never get bored of the food.
#
# I love this place! They have a great selection of beers and wine and they have some good food!<|endoftext|>
# <|startoftext|>I love this place! I had lunch there today. The menu is amazing and the food is amazing. They have the best smoked salmon I've had in a long time. The
# <|endoftext|>The food here is infused with fresh, local ingredients. I personally love the sweet potato and the fried chicken sandwich, but there are many other sandwiches on the menu that are also delicious. If you're looking for a place to go for a quick bite, or to-go, this is your place. You won't be disappointed.
#
# The sandwich is made fresh to order and it comes with a side salad and a glass of watermelon juice. What the heck!? It looks like we got both the quality of
# <|endoftext|>

# %%
gpt2.generate(sess, run_name= 'review_star_5_large_food', length=100, prefix= "I like the", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# I like the great dinner set up here. The live music is great. The patio is clean. The food is on point and I like the large variety of sauces. The best thing about this place is that it's open late and it's worth the drive! I'll be back often!
#
# 5 stars is an understatement and I know, it's a busy Friday!<|endoftext|>
# <|startoftext|>This is by far the best American BBQ I've had in

# %%
gpt2.generate(sess, run_name= 'review_star_5_large_food', length=100, prefix= "I hate the", sample_delim = '<|endoftext|>', include_prefix=False)
# Out:
# I hate the idea of "dessert" with an app I have yet to try.
#
# I love the use of fresh fruit with the app and I love that they have a variety of beer/wine and wine on tap.
#
# I would definitely go back to this place, it's a great addition to the neighborhood.
#
# I've heard good things about the menu.
#
# I'm thinking it'll be good.<|endoftext|>
# <|startof
